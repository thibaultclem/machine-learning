# %% [markdown]
# # LogisticRegression FTR HOME

# %%
# Importing the library
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O
import matplotlib.pyplot as plt # plotting library
import seaborn as sns # visualization library based on matplotlib
from IPython.display import display # Manage multiple output per cell
import datetime

# %%
all_features = ["A_MEANS_FIVE_AC","A_MEANS_FIVE_AF","A_MEANS_FIVE_AR","A_MEANS_FIVE_AS","A_MEANS_FIVE_AST","A_MEANS_FIVE_AY","A_MEANS_FIVE_FTAG","A_MEANS_FIVE_FTHG","A_MEANS_FIVE_FTR_A","A_MEANS_FIVE_FTR_D","A_MEANS_FIVE_FTR_H","A_MEANS_FIVE_HC","A_MEANS_FIVE_HF","A_MEANS_FIVE_HR","A_MEANS_FIVE_HS","A_MEANS_FIVE_HST","A_MEANS_FIVE_HTAG","A_MEANS_FIVE_HTHG","A_MEANS_FIVE_HTR_A","A_MEANS_FIVE_HTR_D","A_MEANS_FIVE_HTR_H","A_MEANS_FIVE_HY","H_MEANS_FIVE_AC","H_MEANS_FIVE_AF","H_MEANS_FIVE_AR","H_MEANS_FIVE_AS","H_MEANS_FIVE_AST","H_MEANS_FIVE_AY","H_MEANS_FIVE_FTAG","H_MEANS_FIVE_FTHG","H_MEANS_FIVE_FTR_A","H_MEANS_FIVE_FTR_D","H_MEANS_FIVE_FTR_H","H_MEANS_FIVE_HC","H_MEANS_FIVE_HF","H_MEANS_FIVE_HR","H_MEANS_FIVE_HS","H_MEANS_FIVE_HST","H_MEANS_FIVE_HTAG","H_MEANS_FIVE_HTHG","H_MEANS_FIVE_HTR_A","H_MEANS_FIVE_HTR_D","H_MEANS_FIVE_HTR_H","H_MEANS_FIVE_HY","A_MEANS_THREE_AC","A_MEANS_THREE_AF","A_MEANS_THREE_AR","A_MEANS_THREE_AS","A_MEANS_THREE_AST","A_MEANS_THREE_AY","A_MEANS_THREE_FTAG","A_MEANS_THREE_FTHG","A_MEANS_THREE_FTR_A","A_MEANS_THREE_FTR_D","A_MEANS_THREE_FTR_H","A_MEANS_THREE_HC","A_MEANS_THREE_HF","A_MEANS_THREE_HR","A_MEANS_THREE_HS","A_MEANS_THREE_HST","A_MEANS_THREE_HTAG","A_MEANS_THREE_HTHG","A_MEANS_THREE_HTR_A","A_MEANS_THREE_HTR_D","A_MEANS_THREE_HTR_H","A_MEANS_THREE_HY","H_MEANS_THREE_AC","H_MEANS_THREE_AF","H_MEANS_THREE_AR","H_MEANS_THREE_AS","H_MEANS_THREE_AST","H_MEANS_THREE_AY","H_MEANS_THREE_FTAG","H_MEANS_THREE_FTHG","H_MEANS_THREE_FTR_A","H_MEANS_THREE_FTR_D","H_MEANS_THREE_FTR_H","H_MEANS_THREE_HC","H_MEANS_THREE_HF","H_MEANS_THREE_HR","H_MEANS_THREE_HS","H_MEANS_THREE_HST","H_MEANS_THREE_HTAG","H_MEANS_THREE_HTHG","H_MEANS_THREE_HTR_A","H_MEANS_THREE_HTR_D","H_MEANS_THREE_HTR_H","H_MEANS_THREE_HY","A_STD_FIVE_AC","A_STD_FIVE_AF","A_STD_FIVE_AR","A_STD_FIVE_AS","A_STD_FIVE_AST","A_STD_FIVE_AY","A_STD_FIVE_FTAG","A_STD_FIVE_FTHG","A_STD_FIVE_FTR_A","A_STD_FIVE_FTR_D","A_STD_FIVE_FTR_H","A_STD_FIVE_HC","A_STD_FIVE_HF","A_STD_FIVE_HR","A_STD_FIVE_HS","A_STD_FIVE_HST","A_STD_FIVE_HTAG","A_STD_FIVE_HTHG","A_STD_FIVE_HTR_A","A_STD_FIVE_HTR_D","A_STD_FIVE_HTR_H","A_STD_FIVE_HY","H_STD_FIVE_AC","H_STD_FIVE_AF","H_STD_FIVE_AR","H_STD_FIVE_AS","H_STD_FIVE_AST","H_STD_FIVE_AY","H_STD_FIVE_FTAG","H_STD_FIVE_FTHG","H_STD_FIVE_FTR_A","H_STD_FIVE_FTR_D","H_STD_FIVE_FTR_H","H_STD_FIVE_HC","H_STD_FIVE_HF","H_STD_FIVE_HR","H_STD_FIVE_HS","H_STD_FIVE_HST","H_STD_FIVE_HTAG","H_STD_FIVE_HTHG","H_STD_FIVE_HTR_A","H_STD_FIVE_HTR_D","H_STD_FIVE_HTR_H","H_STD_FIVE_HY","A_STD_THREE_AC","A_STD_THREE_AF","A_STD_THREE_AR","A_STD_THREE_AS","A_STD_THREE_AST","A_STD_THREE_AY","A_STD_THREE_FTAG","A_STD_THREE_FTHG","A_STD_THREE_FTR_A","A_STD_THREE_FTR_D","A_STD_THREE_FTR_H","A_STD_THREE_HC","A_STD_THREE_HF","A_STD_THREE_HR","A_STD_THREE_HS","A_STD_THREE_HST","A_STD_THREE_HTAG","A_STD_THREE_HTHG","A_STD_THREE_HTR_A","A_STD_THREE_HTR_D","A_STD_THREE_HTR_H","A_STD_THREE_HY","H_STD_THREE_AC","H_STD_THREE_AF","H_STD_THREE_AR","H_STD_THREE_AS","H_STD_THREE_AST","H_STD_THREE_AY","H_STD_THREE_FTAG","H_STD_THREE_FTHG","H_STD_THREE_FTR_A","H_STD_THREE_FTR_D","H_STD_THREE_FTR_H","H_STD_THREE_HC","H_STD_THREE_HF","H_STD_THREE_HR","H_STD_THREE_HS","H_STD_THREE_HST","H_STD_THREE_HTAG","H_STD_THREE_HTHG","H_STD_THREE_HTR_A","H_STD_THREE_HTR_D","H_STD_THREE_HTR_H","H_STD_THREE_HY","INFO_Div"]
best_features = ['A_MEANS_FIVE_AC', 'A_MEANS_FIVE_AS', 'A_MEANS_FIVE_AST',
       'A_MEANS_FIVE_FTAG', 'A_MEANS_FIVE_FTHG', 'A_MEANS_FIVE_FTR_H',
       'A_MEANS_FIVE_HC', 'A_MEANS_FIVE_HF', 'A_MEANS_FIVE_HS',
       'A_MEANS_FIVE_HST', 'A_MEANS_FIVE_HTR_A', 'A_MEANS_FIVE_HY',
       'H_MEANS_FIVE_AC', 'H_MEANS_FIVE_AS', 'H_MEANS_FIVE_AST',
       'H_MEANS_FIVE_AY', 'H_MEANS_FIVE_FTAG', 'H_MEANS_FIVE_FTHG',
       'H_MEANS_FIVE_FTR_A', 'H_MEANS_FIVE_FTR_H', 'H_MEANS_FIVE_HC',
       'H_MEANS_FIVE_HF', 'H_MEANS_FIVE_HS', 'H_MEANS_FIVE_HST',
       'H_MEANS_FIVE_HTAG', 'H_MEANS_FIVE_HTR_H', 'A_MEANS_THREE_AC',
       'A_MEANS_THREE_AS', 'A_MEANS_THREE_FTHG', 'A_MEANS_THREE_HF',
       'A_MEANS_THREE_HS', 'H_MEANS_THREE_AS', 'H_MEANS_THREE_HC',
       'A_STD_FIVE_AST', 'A_STD_FIVE_HC', 'A_STD_FIVE_HF', 'A_STD_FIVE_HS',
       'H_STD_FIVE_AF', 'H_STD_FIVE_AS', 'H_STD_FIVE_AST', 'H_STD_FIVE_HC',
       'H_STD_FIVE_HF', 'H_STD_FIVE_HST']

# %%
model_name = 'LR-all_features'
target = 'INFO_FTR_H'
odd = 'INFO_BbAvH'
bet_on = 'H'
start_date = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M")

# %% [markdown]
# ## Importing Data

# %%
# DB Sqlite connection
import sqlite3
db = "/Users/thibaultclement/Project/ligue1-predict/src/notebook/data/db/soccer_predict.sqlite"
conn = sqlite3.connect(db)
cur = conn.cursor()

# %%
# Get all prematch data
df = pd.read_sql_query("SELECT * FROM pre_matchs ORDER BY INFO_Date ASC;", conn)
df = (df[df.columns.drop(['index'])])
df.shape
# Out:
# (25275, 190)

# %%
# Remove all game between June (include) and October (include)
df['INFO_Date'] = pd.to_datetime(df['INFO_Date'])
df['INFO_Date'].dt.month
df = df[(df['INFO_Date'].dt.month < 6) | (df['INFO_Date'].dt.month > 10)]
df.shape
# Out:
# (18027, 190)

# %%
# Select a particular league
#df = df[(df['INFO_Div'] == 'D1')]
# df = df[(df['INFO_Div'] == 'D1')]
df.shape
# Out:
# (18027, 190)

# %%
# Check the average odd
df[odd].mean()
# Out:
# 2.552546735452375

# %%
# Removing column where odd is too high or too low
# df = df.drop(df[df['INFO_BbAvH'] < 2].index)
# df = df.drop(df[df['INFO_BbAvA'] < 2].index)
# df = df.drop(df[df['INFO_BbAvH'] > 10].index)
# df = df.drop(df[df['INFO_BbAvA'] > 10].index)
df.shape
# Out:
# (18027, 190)

# %%
# Create a INFO_WIN column containing the gain. If bet success it's equal to odd -1, else -1 (loose your bet)
df['INFO_WIN'] = df[odd]-1
df.loc[df.INFO_FTR != bet_on, 'INFO_WIN'] = -1

# %%
# Statistic about winners
display(plt.show(), 100. * df.INFO_FTR.value_counts() / len(df.INFO_FTR))
# Out:
# None
# H    45.515061
# A    28.856715
# D    25.628224
# Name: INFO_FTR, dtype: float64

# %%
# How much did you win/lost per match if bet on all
df.INFO_WIN.mean()
# Out:
# -0.03452709824152642

# %%
# Keep season 2016/2017 for further test and don't use it for traning
import datetime
date_start_current_season = datetime.date(2015, 8, 1)
df_current_season = df[(df['INFO_Date'] > date_start_current_season)]
df = df[(df['INFO_Date'] < date_start_current_season)]

# %%
# Number of matches in current season
df_current_season.shape
# Out:
# (4426, 191)

# %%
# Prepare the dataset
features_list = best_features
X = pd.get_dummies(df[features_list])
y = pd.get_dummies(df)[target].astype('bool_')
X_current_season = pd.get_dummies(df_current_season[features_list])
y_current_season = pd.get_dummies(df_current_season)[target].astype('bool_')

# %% [markdown]
# ## Preprocessing Data

# %%
# Standardize features
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler().fit(X)
X = sc_X.transform(X)
X_current_season = sc_X.transform(X_current_season)

# %%
# Impute of missing values (NaN) with the mean
from sklearn.preprocessing import Imputer
imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
imp = imp.fit(X)
X = imp.transform(X)
X_current_season = imp.transform(X_current_season)

# %%
# Split the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 0)

# %% [markdown]
# ## Tuning Hyper-parameters

# %%
# Import model
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
classifier = LogisticRegression(random_state=0,n_jobs=-1)

# %%
# Applying Grid Search to find the best hyper-parameters for our Model
from sklearn.model_selection import GridSearchCV
from sklearn.metrics.classification import log_loss
from sklearn.metrics import make_scorer
import time

start = time.time()

parameters = [{
    'penalty': ['l1', 'l2'],
    'C': [0.01, 0.1, 1],
    'solver': ['liblinear']
},
{
    'penalty': ['l2'],
    'C': [0.01, 0.1, 1],
    'solver': ['sag', 'lbfgs']
}]
# {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
parameters = [{
    'penalty': ['l1'],
    'C': [0.001, 0.003, 0.01, 0.03],
    'solver': ['liblinear']
}]
# {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
parameters = [{
    'penalty': ['l1'],
    'C': [0.007, 0.008, 0.009, 0.01, 0.02],
    'solver': ['liblinear']
}]
# {'C': 0.008, 'penalty': 'l1', 'solver': 'liblinear'}
parameters = [{
    'penalty': ['l1'],
    'C': [0.008],
    'solver': ['liblinear']
}]
# {'C': 0.008, 'penalty': 'l1', 'solver': 'liblinear'}
# Final
grid_search = GridSearchCV(estimator=classifier,
                           param_grid=parameters,
                           scoring=make_scorer(log_loss, greater_is_better=False),
                           cv=8,
                           n_jobs=-1,
                           verbose=1)
grid_search.fit(X_train, y_train)

time.time() - start
# Out:
# Fitting 8 folds for each of 1 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.6s finished
# 0.8366329669952393

# %%
# Extract best score calculated with the GridSearchCV
best_score = grid_search.best_score_
display(best_score)
# Out:
# -13.43468475121716

# %%
# Extract best hyper-parameter calculated with the GridSearchCV
best_params = grid_search.best_params_
best_params
# Out:
# {'C': 0.008, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
# Get all results of Grid Search
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results.to_csv('./tuning/'+model_name+'-'+target+'_'+start_date+'.csv')
cv_results
# Out:
#    mean_fit_time  mean_score_time  mean_test_score  mean_train_score param_C  \
# 0       0.179881         0.068278       -13.434685        -13.265198   0.008
#
#   param_penalty param_solver  \
# 0            l1    liblinear
#
#                                               params  rank_test_score  \
# 0  {u'penalty': u'l1', u'C': 0.008, u'solver': u'...                1
#
#    split0_test_score       ...         split5_test_score  split5_train_score  \
# 0         -14.239033       ...                -13.177097          -13.330506
#
#    split6_test_score  split6_train_score  split7_test_score  \
# 0         -12.741725          -13.355385         -12.839594
#
#    split7_train_score  std_fit_time  std_score_time  std_test_score  \
# 0          -13.349634      0.050747        0.065564         0.54732
#
#    std_train_score
# 0         0.115585
#
# [1 rows x 29 columns]

# %% [markdown]
# ## Evaluating Model

# %%
# Train a new classifier using the best parameters found by the grid search
clf = LogisticRegression(random_state=0,
                         n_jobs=-1,
                         C=best_params['C'],
                         solver=best_params['solver'],
                         penalty=best_params['penalty']
                        )
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.008, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# Predict target values
y_pred = clf.predict(X_test)

# %%
# Predict probabilities
y_probs = clf.predict_proba(X_test)

# %%
# Compute cross-entropy score
from sklearn.metrics import log_loss
log_loss(y_test, y_pred)
# Out:
# 13.211339408924683

# %%
# Compute precision, recall, F-measure and support
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, y_pred, average='binary')
# Out:
# (0.60369318181818177, 0.45871559633027525, 0.52131248083409998, None)

# %%
# Compute the confusion Matrix
df_confusion = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
df_confusion
# Out:
# Predicted  False  True   All
# Actual
# False       1670   558  2228
# True        1003   850  1853
# All         2673  1408  4081

# %%
# Plot a ROC curve
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test.ravel(), y_probs[:, 1].ravel())
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('ROC')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# # ALL DATASET TEST

# %%
# Apply on all the dataset
X_pred = clf.predict(X)
df['pred'] = X_pred
df_bet_all_seasons = df.drop(df[df.pred == 0].index)

# %%
# How many bet I did
df_bet_all_seasons.shape
# Out:
# (4750, 192)

# %%
# What will be the real result of games I bet on
display(plt.show(), 100. * df_bet_all_seasons.INFO_FTR.value_counts() / len(df_bet_all_seasons.INFO_FTR))
# Out:
# None
# H    59.852632
# D    22.336842
# A    17.810526
# Name: INFO_FTR, dtype: float64

# %%
# Compute cross-entropy score
log_loss(y, X_pred)
# Out:
# 13.281326768449544

# %%
# Score for all dataset
precision_recall_fscore_support(y, X_pred, average='binary')
# Out:
# (0.59852631578947368, 0.46107687317547841, 0.52088677171124942, None)

# %%
# Making the confusion Matrix
df_confusion = pd.crosstab(y, X_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
df_confusion
# Out:
# Predicted  False  True    All
# Actual
# False       5528  1907   7435
# True        3323  2843   6166
# All         8851  4750  13601

# %%
df_bet_all_seasons.INFO_WIN.mean()
# Out:
# -0.002292631578947375

# %% [markdown]
# # SEASON 2016/2017 TEST

# %%
# Apply on current season that is not use for train and test set
X_pred_current_season = clf.predict(X_current_season)
X_prob_current_season = clf.predict_proba(X_current_season)
df_current_season['pred'] = X_pred_current_season
df_current_season['prob'] = X_prob_current_season[:,1:]
df_current_season['prob_less_bet'] = df_current_season['prob'] - df_current_season[odd].apply(lambda x: 1/x)

# %%
# Remove games I didn't bet on
df_bet_current_season = df_current_season.drop(df_current_season[df_current_season.pred == 0].index)
df_bet_current_season = df_bet_current_season[df_bet_current_season.prob_less_bet > 0]
# df_bet_away_current_season = df_bet_away_current_season[df_bet_away_current_season[odd] > 2]
# df_bet_away_current_season = df_bet_away_current_season[df_bet_away_current_season[odd] < 4]

# %%
# How many bet I did
df_bet_current_season.shape
# Out:
# (588, 194)

# %%
# How many matches was play
X_pred_current_season.shape
# Out:
# (4426,)

# %%
# What will be the real result of games I bet on
display(plt.show(), 100. * df_bet_current_season.INFO_FTR.value_counts() / len(df_bet_current_season.INFO_FTR))
# Out:
# None
# H    48.639456
# A    26.190476
# D    25.170068
# Name: INFO_FTR, dtype: float64

# %%
# Compute cross-entropy score
log_loss(y_current_season, X_pred_current_season)
# Out:
# 13.50815239668102

# %%
# Score for this current season
precision_recall_fscore_support(y_current_season, X_pred_current_season, average='binary')
# Out:
# (0.60547945205479448, 0.43354585581167238, 0.5052872249214061, None)

# %%
# Making the confusion Matrix
df_confusion = pd.crosstab(y_current_season, X_pred_current_season, rownames=['Actual'], colnames=['Predicted'], margins=True)
df_confusion
# Out:
# Predicted  False  True   All
# Actual
# False       1811   576  2387
# True        1155   884  2039
# All         2966  1460  4426

# %%
# What I win/lost on each match
df_bet_current_season.INFO_WIN.mean()
# Out:
# 0.01403061224489795

# %%
df_bet_current_season.INFO_BbAvH.mean()
# Out:
# 2.1849319727891143

# %%
df_bet_current_season
# Out:
#        A_MEANS_FIVE_AC  A_MEANS_FIVE_AF  A_MEANS_FIVE_AR  A_MEANS_FIVE_AS  \
# 19924              3.6             18.6              0.4             11.2
# 19941              3.4             11.8              0.2              7.6
# 19946              4.0             12.0              0.0              9.0
# 19955              1.6             10.4              0.0             10.2
# 19958              5.8              9.6              0.4             10.4
# 19972              4.4             13.8              0.0             12.4
# 19973              6.4             11.2              0.0             11.8
# 19984              4.2             11.0              0.0             10.4
# 19987              3.0             12.6              0.2              7.8
# 20000              4.4             17.2              0.0             12.2
# 20006              6.8             15.0              0.4             10.6
# 20015              6.8             10.4              0.2              8.6
# 20016              5.4             10.2              0.2              9.4
# 20020              6.6             11.4              0.0              8.8
# 20021              3.4             12.6              0.2              6.4
# 20032              2.2             17.4              0.0              7.6
# 20036              7.2             15.0              0.0             12.8
# 20045              3.0             10.8              0.2              8.6
# 20053              5.8             13.2              0.0             10.6
# 20056              2.8              9.8              0.0              6.2
# 20064              6.6             12.6              0.2             10.2
# 20067              4.4             12.6              0.0              6.0
# 20073              7.6              7.8              0.0             16.6
# 20078              3.8             12.8              0.2              7.8
# 20088              5.2             16.2              0.2             11.8
# 20089              4.4             17.8              0.0              8.8
# 20099              3.4             15.6              0.0              9.8
# 20111              4.8             14.6              0.0             11.4
# 20117              4.6             11.2              0.0             12.2
# 20119              2.8             12.2              0.2              7.8
# ...                ...              ...              ...              ...
# 25041              4.6             12.2              0.0             12.4
# 25044              6.6             11.0              0.0             10.0
# 25047              7.4             11.2              0.0             12.2
# 25073              2.8             16.0              0.2              9.6
# 25082              5.0             14.4              0.0             13.4
# 25084              3.8             13.2              0.0              8.8
# 25089              3.2             13.2              0.2              7.8
# 25090              2.8             13.8              0.2              8.8
# 25112              4.4             12.0              0.0             10.0
# 25113              3.8             11.0              0.0             11.8
# 25114              3.4             13.2              0.0              6.8
# 25120              5.2             12.2              0.2              9.2
# 25151              4.4             15.6              0.0              8.2
# 25154              4.0             12.2              0.0             11.4
# 25161              3.2             11.4              0.2             10.2
# 25166              3.6             14.2              0.4             10.8
# 25168              5.6              9.2              0.2              9.0
# 25169              4.8             12.4              0.2             11.4
# 25174              4.2             14.6              0.4              7.2
# 25178              5.6             11.0              0.2             10.4
# 25201              4.6             13.2              0.2              8.6
# 25218              4.6             14.2              0.2             15.0
# 25220              5.6              9.0              0.2             12.0
# 25221              2.4             12.0              0.2              8.8
# 25243              2.6              9.2              0.2              8.4
# 25245              5.0             11.0              0.0              9.4
# 25247              4.4             12.8              0.0              8.4
# 25252              7.8             14.8              0.2             15.8
# 25255              3.0              9.4              0.2             10.4
# 25260              4.4             14.2              0.2              7.8
#
#        A_MEANS_FIVE_AST  A_MEANS_FIVE_AY  A_MEANS_FIVE_FTAG  \
# 19924               2.4              3.2                0.8
# 19941               2.8              1.8                0.4
# 19946               4.0              1.6                0.6
# 19955               5.0              1.4                1.6
# 19958               3.6              1.6                0.2
# 19972               5.6              3.6                1.6
# 19973               3.4              2.8                1.0
# 19984               3.2              3.8                0.6
# 19987               3.0              2.2                1.0
# 20000               4.6              1.6                1.0
# 20006               2.4              2.4                0.8
# 20015               2.6              2.0                0.6
# 20016               2.8              1.2                0.6
# 20020               3.8              2.4                1.6
# 20021               2.6              1.4                0.6
# 20032               2.4              2.8                1.2
# 20036               5.2              3.0                1.0
# 20045               2.6              2.6                0.4
# 20053               3.6              2.8                1.4
# 20056               2.4              1.8                0.6
# 20064               3.6              2.0                0.6
# 20067               2.8              2.2                0.4
# 20073               6.2              1.8                1.4
# 20078               2.8              1.0                0.6
# 20088               4.8              2.6                1.0
# 20089               3.4              2.8                0.8
# 20099               3.8              3.0                0.2
# 20111               4.4              2.2                1.4
# 20117               3.6              1.6                1.2
# 20119               3.2              2.6                1.2
# ...                 ...              ...                ...
# 25041               3.6              2.2                1.6
# 25044               3.4              1.2                1.0
# 25047               4.4              1.6                0.6
# 25073               2.4              3.0                0.8
# 25082               4.8              2.4                1.0
# 25084               2.4              2.8                0.0
# 25089               3.0              2.4                0.8
# 25090               4.6              2.8                1.2
# 25112               3.2              2.2                0.8
# 25113               5.2              2.0                1.6
# 25114               1.6              2.0                0.4
# 25120               2.4              1.0                0.6
# 25151               3.0              2.0                0.2
# 25154               3.0              1.2                0.8
# 25161               3.8              3.0                1.2
# 25166               3.2              2.6                0.6
# 25168               1.8              1.6                0.6
# 25169               5.2              1.4                1.6
# 25174               2.6              2.4                0.4
# 25178               3.8              1.4                0.2
# 25201               3.6              1.8                0.6
# 25218               5.4              2.2                1.2
# 25220               3.2              1.0                0.8
# 25221               3.8              1.4                1.0
# 25243               2.8              1.2                0.8
# 25245               3.0              1.8                1.4
# 25247               2.0              2.8                0.6
# 25252               5.6              1.0                2.4
# 25255               4.2              1.8                1.6
# 25260               3.2              3.6                0.8
#
#        A_MEANS_FIVE_FTHG  A_MEANS_FIVE_FTR_A  A_MEANS_FIVE_FTR_D  \
# 19924                1.4                 0.2                 0.2
# 19941                2.2                 0.0                 0.0
# 19946                2.0                 0.0                 0.2
# 19955                2.6                 0.4                 0.0
# 19958                2.6                 0.0                 0.2
# 19972                1.2                 0.6                 0.0
# 19973                1.4                 0.2                 0.2
# 19984                1.2                 0.2                 0.2
# 19987                1.4                 0.4                 0.4
# 20000                1.2                 0.6                 0.0
# 20006                2.8                 0.2                 0.0
# 20015                1.4                 0.2                 0.0
# 20016                2.4                 0.2                 0.0
# 20020                1.4                 0.6                 0.0
# 20021                2.2                 0.2                 0.0
# 20032                2.6                 0.0                 0.4
# 20036                1.0                 0.2                 0.6
# 20045                0.8                 0.0                 0.6
# 20053                1.6                 0.4                 0.0
# 20056                2.0                 0.0                 0.2
# 20064                2.8                 0.0                 0.4
# 20067                1.4                 0.0                 0.4
# 20073                1.4                 0.6                 0.0
# 20078                2.0                 0.2                 0.4
# 20088                1.2                 0.4                 0.2
# 20089                2.0                 0.0                 0.2
# 20099                2.6                 0.0                 0.2
# 20111                2.2                 0.2                 0.0
# 20117                0.6                 0.6                 0.2
# 20119                0.4                 0.6                 0.4
# ...                  ...                 ...                 ...
# 25041                1.2                 0.6                 0.2
# 25044                2.6                 0.2                 0.0
# 25047                1.2                 0.2                 0.2
# 25073                1.6                 0.2                 0.4
# 25082                2.0                 0.2                 0.0
# 25084                1.8                 0.0                 0.2
# 25089                1.4                 0.0                 0.6
# 25090                2.2                 0.0                 0.4
# 25112                1.4                 0.0                 0.6
# 25113                2.8                 0.4                 0.0
# 25114                1.0                 0.0                 0.6
# 25120                1.4                 0.0                 0.4
# 25151                3.4                 0.0                 0.2
# 25154                1.0                 0.2                 0.4
# 25161                2.4                 0.2                 0.0
# 25166                1.0                 0.2                 0.2
# 25168                2.6                 0.0                 0.2
# 25169                0.6                 0.6                 0.2
# 25174                1.6                 0.0                 0.0
# 25178                2.8                 0.0                 0.2
# 25201                2.0                 0.2                 0.2
# 25218                1.6                 0.4                 0.0
# 25220                2.0                 0.2                 0.0
# 25221                3.0                 0.2                 0.2
# 25243                1.4                 0.2                 0.6
# 25245                2.0                 0.6                 0.0
# 25247                2.0                 0.0                 0.4
# 25252                2.2                 0.2                 0.2
# 25255                2.2                 0.4                 0.2
# 25260                1.4                 0.4                 0.0
#
#            ...        INFO_FTR  INFO_HTR       INFO_HomeTeam  INFO_PSA  \
# 19924      ...               A         A               Lazio      4.17
# 19941      ...               H         H  Milton Keynes Dons      3.54
# 19946      ...               H         H            Coventry      4.45
# 19955      ...               A         D          Leverkusen      6.89
# 19958      ...               A         A         Bournemouth      3.57
# 19972      ...               H         H                Hull      3.04
# 19973      ...               D         D                 QPR      3.44
# 19984      ...               A         A               Celta      4.46
# 19987      ...               A         D              Malaga      4.43
# 20000      ...               H         H                Lyon      4.07
# 20006      ...               H         H                Roma      3.91
# 20015      ...               A         A            Barnsley      3.02
# 20016      ...               A         A           Blackpool      2.85
# 20020      ...               H         H          Gillingham      3.49
# 20021      ...               H         D           Peterboro      3.80
# 20032      ...               A         A           Stuttgart      3.89
# 20036      ...               A         A            Man City      5.56
# 20045      ...               H         D               Derby      6.68
# 20053      ...               H         H            Coventry      3.62
# 20056      ...               H         H      Fleetwood Town      3.83
# 20064      ...               H         D            Guingamp      3.76
# 20067      ...               H         D         Montpellier      3.98
# 20073      ...               A         A         Real Madrid      2.87
# 20078      ...               D         H              Hearts      4.74
# 20088      ...               A         A          St Etienne      3.18
# 20089      ...               A         D            Atalanta      2.88
# 20099      ...               A         A            Sp Gijon      3.78
# 20111      ...               H         D           Peterboro      3.56
# 20117      ...               A         A                Hull      3.49
# 20119      ...               A         A             Levante      4.02
# ...        ...             ...       ...                 ...       ...
# 25041      ...               A         D             Everton      2.03
# 25044      ...               H         D           Tottenham      4.15
# 25047      ...               A         A         Bristol Rvs      2.08
# 25073      ...               H         D              Malaga      1.96
# 25082      ...               D         D          Ingolstadt      2.98
# 25084      ...               D         A         Bournemouth      3.47
# 25089      ...               H         H             Swansea      2.65
# 25090      ...               H         H            Guingamp      3.48
# 25112      ...               A         A        Bristol City      2.70
# 25113      ...               A         A              Burton      3.22
# 25114      ...               A         A        Huddersfield      3.36
# 25120      ...               D         H               Wigan      2.41
# 25151      ...               D         H          Schalke 04      3.76
# 25154      ...               H         H         Bournemouth      4.28
# 25161      ...               A         D             Espanol      3.13
# 25166      ...               H         H             Rangers      4.37
# 25168      ...               H         H      Crystal Palace      3.69
# 25169      ...               H         H           Tottenham      5.35
# 25174      ...               H         D               Dijon      3.98
# 25178      ...               H         H              Nantes      3.95
# 25201      ...               H         D         Ross County      3.28
# 25218      ...               D         D          Ingolstadt      2.62
# 25220      ...               H         D              Angers      3.66
# 25221      ...               H         H            Guingamp      5.35
# 25243      ...               D         A           Leicester      4.35
# 25245      ...               H         H          Man United      3.14
# 25247      ...               H         A             Swansea      3.67
# 25252      ...               A         A               Lazio      3.63
# 25255      ...               D         H             Udinese      3.81
# 25260      ...               A         A            Valencia      2.32
#
#        INFO_PSD  INFO_PSH  INFO_WIN  pred      prob  prob_less_bet
# 19924      3.47      2.03     -1.00  True  0.567600       0.070088
# 19941      3.45      2.20      1.11  True  0.617830       0.143896
# 19946      3.80      1.86      0.83  True  0.584971       0.038523
# 19955      4.72      1.51     -1.00  True  0.685023       0.009347
# 19958      3.56      2.18     -1.00  True  0.527856       0.073311
# 19972      3.18      2.62      1.50  True  0.501656       0.101656
# 19973      3.32      2.31     -1.00  True  0.502062       0.053631
# 19984      3.87      1.86     -1.00  True  0.610990       0.073355
# 19987      3.64      1.93     -1.00  True  0.570258       0.052124
# 20000      3.66      1.97      0.93  True  0.535560       0.017425
# 20006      3.67      2.03      0.96  True  0.600479       0.090275
# 20015      3.46      2.50     -1.00  True  0.502844       0.093008
# 20016      3.31      2.69     -1.00  True  0.552313       0.166213
# 20020      3.74      2.12      1.08  True  0.515231       0.034462
# 20021      3.72      2.03      0.98  True  0.513020       0.007970
# 20032      3.95      1.96     -1.00  True  0.586525       0.068390
# 20036      4.15      1.67     -1.00  True  0.658705       0.056295
# 20045      4.03      1.60      0.56  True  0.652282       0.011256
# 20053      3.70      2.09      1.08  True  0.541073       0.060304
# 20056      3.71      2.02      1.00  True  0.516990       0.016990
# 20064      3.44      2.14      1.07  True  0.531699       0.048607
# 20067      3.38      2.09      1.07  True  0.555653       0.072561
# 20073      3.74      2.47     -1.00  True  0.549879       0.140043
# 20078      3.89      1.79     -1.00  True  0.564324       0.002526
# 20088      3.35      2.43     -1.00  True  0.522098       0.110576
# 20089      3.26      2.73     -1.00  True  0.569285       0.187606
# 20099      3.39      2.17     -1.00  True  0.502825       0.039862
# 20111      3.83      2.07      0.99  True  0.513216       0.010703
# 20117      3.34      2.31     -1.00  True  0.548790       0.114008
# 20119      3.47      2.07     -1.00  True  0.519523       0.038754
# ...         ...       ...       ...   ...       ...            ...
# 25041      3.67      3.77     -1.00  True  0.535833       0.264094
# 25044      3.94      1.86      0.88  True  0.739782       0.207867
# 25047      3.90      3.48     -1.00  True  0.507363       0.208856
# 25073      3.80      3.90      2.73  True  0.511627       0.243530
# 25082      3.61      2.46     -1.00  True  0.544577       0.134741
# 25084      3.50      2.24     -1.00  True  0.565421       0.110876
# 25089      3.48      2.81      1.76  True  0.551991       0.189672
# 25090      3.69      2.14      1.12  True  0.624820       0.153122
# 25112      3.65      2.63     -1.00  True  0.527472       0.139875
# 25113      3.57      2.30     -1.00  True  0.502190       0.053760
# 25114      3.61      2.22     -1.00  True  0.546764       0.083801
# 25120      3.49      3.10     -1.00  True  0.572537       0.238089
# 25151      3.82      2.03     -1.00  True  0.600706       0.105656
# 25154      3.76      1.93      0.92  True  0.560817       0.039983
# 25161      3.61      2.36     -1.00  True  0.503086       0.079357
# 25166      3.79      1.88      0.86  True  0.539990       0.002356
# 25168      3.63      2.11      1.06  True  0.521249       0.035812
# 25169      4.04      1.71      0.70  True  0.613352       0.025116
# 25174      3.62      2.01      1.01  True  0.515964       0.018451
# 25178      3.52      2.05      1.04  True  0.595236       0.105040
# 25201      3.52      2.29      1.23  True  0.502531       0.054101
# 25218      3.77      2.68     -1.00  True  0.517006       0.135327
# 25220      3.60      2.11      1.11  True  0.536267       0.062333
# 25221      4.09      1.68      0.66  True  0.653310       0.050900
# 25243      3.75      1.91     -1.00  True  0.618095       0.097261
# 25245      3.40      2.44      1.48  True  0.609466       0.206241
# 25247      3.68      2.10      1.06  True  0.579107       0.093670
# 25252      3.95      2.04     -1.00  True  0.525469       0.027957
# 25255      3.52      2.11     -1.00  True  0.541002       0.060233
# 25260      3.74      3.11     -1.00  True  0.650350       0.317016
#
# [588 rows x 194 columns]

# %%
#df_bet_current_season.to_csv('SVM_2016_2017.csv')

# %% [markdown]
# # Learning Curve

# %%
# Plot a leqrning curve
from sklearn.datasets import load_digits
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit


def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring='f1')
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

plot_learning_curve(clf, 'Learning Curve', X, y, cv=4, n_jobs=-1).show()
plt.show()
# Out:
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
