# %% [markdown]
# # Decision Tree FTR HOME

# %%
# Importing the library
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O
import matplotlib.pyplot as plt # plotting library
import seaborn as sns # visualization library based on matplotlib
from IPython.display import display # Manage multiple output per cell
import datetime

# %%
all_features = ["A_MEANS_FIVE_AC","A_MEANS_FIVE_AF","A_MEANS_FIVE_AR","A_MEANS_FIVE_AS","A_MEANS_FIVE_AST","A_MEANS_FIVE_AY","A_MEANS_FIVE_FTAG","A_MEANS_FIVE_FTHG","A_MEANS_FIVE_FTR_A","A_MEANS_FIVE_FTR_D","A_MEANS_FIVE_FTR_H","A_MEANS_FIVE_HC","A_MEANS_FIVE_HF","A_MEANS_FIVE_HR","A_MEANS_FIVE_HS","A_MEANS_FIVE_HST","A_MEANS_FIVE_HTAG","A_MEANS_FIVE_HTHG","A_MEANS_FIVE_HTR_A","A_MEANS_FIVE_HTR_D","A_MEANS_FIVE_HTR_H","A_MEANS_FIVE_HY","H_MEANS_FIVE_AC","H_MEANS_FIVE_AF","H_MEANS_FIVE_AR","H_MEANS_FIVE_AS","H_MEANS_FIVE_AST","H_MEANS_FIVE_AY","H_MEANS_FIVE_FTAG","H_MEANS_FIVE_FTHG","H_MEANS_FIVE_FTR_A","H_MEANS_FIVE_FTR_D","H_MEANS_FIVE_FTR_H","H_MEANS_FIVE_HC","H_MEANS_FIVE_HF","H_MEANS_FIVE_HR","H_MEANS_FIVE_HS","H_MEANS_FIVE_HST","H_MEANS_FIVE_HTAG","H_MEANS_FIVE_HTHG","H_MEANS_FIVE_HTR_A","H_MEANS_FIVE_HTR_D","H_MEANS_FIVE_HTR_H","H_MEANS_FIVE_HY","A_MEANS_THREE_AC","A_MEANS_THREE_AF","A_MEANS_THREE_AR","A_MEANS_THREE_AS","A_MEANS_THREE_AST","A_MEANS_THREE_AY","A_MEANS_THREE_FTAG","A_MEANS_THREE_FTHG","A_MEANS_THREE_FTR_A","A_MEANS_THREE_FTR_D","A_MEANS_THREE_FTR_H","A_MEANS_THREE_HC","A_MEANS_THREE_HF","A_MEANS_THREE_HR","A_MEANS_THREE_HS","A_MEANS_THREE_HST","A_MEANS_THREE_HTAG","A_MEANS_THREE_HTHG","A_MEANS_THREE_HTR_A","A_MEANS_THREE_HTR_D","A_MEANS_THREE_HTR_H","A_MEANS_THREE_HY","H_MEANS_THREE_AC","H_MEANS_THREE_AF","H_MEANS_THREE_AR","H_MEANS_THREE_AS","H_MEANS_THREE_AST","H_MEANS_THREE_AY","H_MEANS_THREE_FTAG","H_MEANS_THREE_FTHG","H_MEANS_THREE_FTR_A","H_MEANS_THREE_FTR_D","H_MEANS_THREE_FTR_H","H_MEANS_THREE_HC","H_MEANS_THREE_HF","H_MEANS_THREE_HR","H_MEANS_THREE_HS","H_MEANS_THREE_HST","H_MEANS_THREE_HTAG","H_MEANS_THREE_HTHG","H_MEANS_THREE_HTR_A","H_MEANS_THREE_HTR_D","H_MEANS_THREE_HTR_H","H_MEANS_THREE_HY","A_STD_FIVE_AC","A_STD_FIVE_AF","A_STD_FIVE_AR","A_STD_FIVE_AS","A_STD_FIVE_AST","A_STD_FIVE_AY","A_STD_FIVE_FTAG","A_STD_FIVE_FTHG","A_STD_FIVE_FTR_A","A_STD_FIVE_FTR_D","A_STD_FIVE_FTR_H","A_STD_FIVE_HC","A_STD_FIVE_HF","A_STD_FIVE_HR","A_STD_FIVE_HS","A_STD_FIVE_HST","A_STD_FIVE_HTAG","A_STD_FIVE_HTHG","A_STD_FIVE_HTR_A","A_STD_FIVE_HTR_D","A_STD_FIVE_HTR_H","A_STD_FIVE_HY","H_STD_FIVE_AC","H_STD_FIVE_AF","H_STD_FIVE_AR","H_STD_FIVE_AS","H_STD_FIVE_AST","H_STD_FIVE_AY","H_STD_FIVE_FTAG","H_STD_FIVE_FTHG","H_STD_FIVE_FTR_A","H_STD_FIVE_FTR_D","H_STD_FIVE_FTR_H","H_STD_FIVE_HC","H_STD_FIVE_HF","H_STD_FIVE_HR","H_STD_FIVE_HS","H_STD_FIVE_HST","H_STD_FIVE_HTAG","H_STD_FIVE_HTHG","H_STD_FIVE_HTR_A","H_STD_FIVE_HTR_D","H_STD_FIVE_HTR_H","H_STD_FIVE_HY","A_STD_THREE_AC","A_STD_THREE_AF","A_STD_THREE_AR","A_STD_THREE_AS","A_STD_THREE_AST","A_STD_THREE_AY","A_STD_THREE_FTAG","A_STD_THREE_FTHG","A_STD_THREE_FTR_A","A_STD_THREE_FTR_D","A_STD_THREE_FTR_H","A_STD_THREE_HC","A_STD_THREE_HF","A_STD_THREE_HR","A_STD_THREE_HS","A_STD_THREE_HST","A_STD_THREE_HTAG","A_STD_THREE_HTHG","A_STD_THREE_HTR_A","A_STD_THREE_HTR_D","A_STD_THREE_HTR_H","A_STD_THREE_HY","H_STD_THREE_AC","H_STD_THREE_AF","H_STD_THREE_AR","H_STD_THREE_AS","H_STD_THREE_AST","H_STD_THREE_AY","H_STD_THREE_FTAG","H_STD_THREE_FTHG","H_STD_THREE_FTR_A","H_STD_THREE_FTR_D","H_STD_THREE_FTR_H","H_STD_THREE_HC","H_STD_THREE_HF","H_STD_THREE_HR","H_STD_THREE_HS","H_STD_THREE_HST","H_STD_THREE_HTAG","H_STD_THREE_HTHG","H_STD_THREE_HTR_A","H_STD_THREE_HTR_D","H_STD_THREE_HTR_H","H_STD_THREE_HY","INFO_Div"]
best_features =

# %%
model_name = 'DecisionTree-all_features'
target = 'INFO_FTR_H'
odd = 'INFO_BbAvH'
bet_on = 'H'
start_date = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M")

# %% [markdown]
# ## Importing Data

# %%
# DB Sqlite connection
import sqlite3
db = "/Users/thibaultclement/Project/ligue1-predict/src/notebook/data/db/soccer_predict.sqlite"
conn = sqlite3.connect(db)
cur = conn.cursor()

# %%
# Get all prematch data
df = pd.read_sql_query("SELECT * FROM pre_matchs ORDER BY INFO_Date ASC;", conn)
df = (df[df.columns.drop(['index'])])
df.shape
# Out:
# (25275, 190)

# %%
# Remove all game between June (include) and October (include)
df['INFO_Date'] = pd.to_datetime(df['INFO_Date'])
df['INFO_Date'].dt.month
df = df[(df['INFO_Date'].dt.month < 6) | (df['INFO_Date'].dt.month > 10)]
df.shape
# Out:
# (18027, 190)

# %%
# Select a particular league
#df = df[(df['INFO_Div'] == 'D1')]
#df = df[(df['INFO_Div'] == 'E0')]
df.shape
# Out:
# (18027, 190)

# %%
# Check the average odd
df[odd].mean()
# Out:
# 2.552546735452375

# %%
# Removing column where odd is too high or too low
# df = df.drop(df[df['INFO_BbAvH'] < 2].index)
# df = df.drop(df[df['INFO_BbAvA'] < 2].index)
# df = df.drop(df[df['INFO_BbAvH'] > 10].index)
# df = df.drop(df[df['INFO_BbAvA'] > 10].index)
df.shape
# Out:
# (18027, 190)

# %%
# Create a INFO_WIN column containing the gain. If bet success it's equal to odd -1, else -1 (loose your bet)
df['INFO_WIN'] = df[odd]-1
df.loc[df.INFO_FTR != bet_on, 'INFO_WIN'] = -1

# %%
# Statistic about winners
display(plt.show(), 100. * df.INFO_FTR.value_counts() / len(df.INFO_FTR))
# Out:
# None
# H    45.515061
# A    28.856715
# D    25.628224
# Name: INFO_FTR, dtype: float64

# %%
# How much did you win/lost per match if bet on all
df.INFO_WIN.mean()
# Out:
# -0.03452709824152642

# %%
# Keep season 2016/2017 for further test and don't use it for traning
import datetime
date_start_current_season = datetime.date(2016, 8, 1)
df_current_season = df[(df['INFO_Date'] > date_start_current_season)]
df = df[(df['INFO_Date'] < date_start_current_season)]

# %%
# Number of matches in current season
df_current_season.shape
# Out:
# (2222, 191)

# %%
# Prepare the dataset
features_list = best_features
X = pd.get_dummies(df[features_list])
y = pd.get_dummies(df)[target].astype('bool_')
X_current_season = pd.get_dummies(df_current_season[features_list])
y_current_season = pd.get_dummies(df_current_season)[target].astype('bool_')

# %% [markdown]
# ## Preprocessing Data

# %%
# Standardize features
#from sklearn.preprocessing import StandardScaler
#sc_X = StandardScaler().fit(X)
#X = sc_X.transform(X)
#X_current_season = sc_X.transform(X_current_season)

# %%
# Impute of missing values (NaN) with the mean
from sklearn.preprocessing import Imputer
imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
imp = imp.fit(X)
X = imp.transform(X)
X_current_season = imp.transform(X_current_season)

# %%
# Split the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 0)

# %% [markdown]
# ## Tuning Hyper-parameters

# %%
# Import model
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
classifier = DecisionTreeClassifier(random_state=0)

# %%
# Applying Grid Search to find the best hyper-parameters for our Model
from sklearn.model_selection import GridSearchCV
from sklearn.metrics.classification import log_loss
from sklearn.metrics import make_scorer
import time

start = time.time()

parameters = [{
    'max_features': ['sqrt', None],
    'criterion': ['entropy'],
    'max_depth': [5, 10, 15, 20],
    'min_samples_split': [10, 30, 50, 70, 100],
    'min_samples_leaf': [2, 3, 5]
}]
# {'criterion': 'entropy','max_depth': 5,'max_features': None,'min_samples_leaf': 3,'min_samples_split': 50}
parameters = [{
    'max_features': [None],
    'criterion': ['entropy'],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'min_samples_split': [10, 30, 50, 70],
    'min_samples_leaf': [2, 3, 4]
}]
# {'criterion': 'entropy','max_depth': 6,'max_features': None,'min_samples_leaf': 3,'min_samples_split': 50}
parameters = [{
    'max_features': [None],
    'criterion': ['entropy'],
    'max_depth': [5, 6, 7],
    'min_samples_split': [40, 45, 50, 55, 60],
    'min_samples_leaf': [2, 3, 4]
}]
# {'criterion': 'entropy', 'max_depth': 6,'max_features': None,'min_samples_leaf': 4,'min_samples_split': 40}
parameters = [{
    'max_features': [None],
    'criterion': ['entropy'],
    'max_depth': [5, 6, 7],
    'min_samples_split': [35, 40, 45],
    'min_samples_leaf': [2, 3, 4, 5]
}]
# {'criterion': 'entropy','max_depth': 6,'max_features': None,'min_samples_leaf': 5,'min_samples_split': 35}
# FINAL NOT GOOD
grid_search = GridSearchCV(estimator=classifier,
                           param_grid=parameters,
                           scoring=make_scorer(log_loss, greater_is_better=False),
                           cv=8,
                           n_jobs=-1,
                           verbose=1)
grid_search.fit(X_train, y_train)

time.time() - start
# Out:
# Fitting 8 folds for each of 36 candidates, totalling 288 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 288 out of 288 | elapsed:  1.6min finished
# 99.67979907989502

# %%
# Extract best score calculated with the GridSearchCV
best_score = grid_search.best_score_
display(best_score)
# Out:
# -14.333248072347024

# %%
# Extract best hyper-parameter calculated with the GridSearchCV
best_params = grid_search.best_params_
best_params
# Out:
# {'criterion': 'entropy',
#  'max_depth': 6,
#  'max_features': None,
#  'min_samples_leaf': 5,
#  'min_samples_split': 35}

# %%
# Get all results of Grid Search
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results.to_csv('./tuning/'+model_name+'-'+target+'_'+start_date+'.csv')
cv_results
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0        1.014996         0.012063       -14.579894        -13.239202
# 1        1.515374         0.012486       -14.579894        -13.239202
# 2        1.267505         0.004698       -14.586138        -13.243216
# 3        1.179107         0.018802       -14.573650        -13.240094
# 4        1.306168         0.009988       -14.573650        -13.240094
# 5        1.176798         0.006254       -14.579894        -13.244108
# 6        1.303389         0.008367       -14.573650        -13.241432
# 7        1.032801         0.004575       -14.573650        -13.241432
# 8        1.195949         0.006888       -14.579894        -13.245446
# 9        1.013575         0.008587       -14.570528        -13.248122
# 10       1.096363         0.007023       -14.570528        -13.248122
# 11       1.138962         0.008071       -14.579894        -13.250352
# 12       1.211107         0.008187       -14.348858        -12.806122
# 13       1.227244         0.004923       -14.348858        -12.809690
# 14       1.170449         0.006925       -14.364468        -12.825300
# 15       1.380648         0.011178       -14.342614        -12.807014
# 16       1.619306         0.007031       -14.342614        -12.810583
# 17       1.170752         0.009433       -14.358224        -12.826192
# 18       1.308895         0.008256       -14.336370        -12.811475
# 19       1.410651         0.004182       -14.339492        -12.815043
# 20       1.496688         0.004418       -14.358224        -12.829314
# 21       1.190192         0.008659       -14.333248        -12.822625
# 22       1.304559         0.005226       -14.333248        -12.825747
# 23       1.365057         0.005745       -14.355102        -12.838235
# 24       1.394275         0.004251       -14.386316        -12.326215
# 25       1.420600         0.008941       -14.380072        -12.330675
# 26       1.456594         0.006121       -14.370706        -12.351191
# 27       1.380532         0.007988       -14.380072        -12.327999
# 28       1.373544         0.004451       -14.370706        -12.332459
# 29       1.621608         0.008204       -14.361340        -12.352975
# 30       1.267450         0.004041       -14.373828        -12.336919
# 31       1.485678         0.006526       -14.364462        -12.342271
# 32       1.346122         0.011015       -14.358217        -12.361449
# 33       1.408097         0.005662       -14.376950        -12.350300
# 34       1.387910         0.005661       -14.364462        -12.355206
# 35       1.252947         0.005194       -14.361340        -12.374830
#
#    param_criterion param_max_depth param_max_features param_min_samples_leaf  \
# 0          entropy               5               None                      2
# 1          entropy               5               None                      2
# 2          entropy               5               None                      2
# 3          entropy               5               None                      3
# 4          entropy               5               None                      3
# 5          entropy               5               None                      3
# 6          entropy               5               None                      4
# 7          entropy               5               None                      4
# 8          entropy               5               None                      4
# 9          entropy               5               None                      5
# 10         entropy               5               None                      5
# 11         entropy               5               None                      5
# 12         entropy               6               None                      2
# 13         entropy               6               None                      2
# 14         entropy               6               None                      2
# 15         entropy               6               None                      3
# 16         entropy               6               None                      3
# 17         entropy               6               None                      3
# 18         entropy               6               None                      4
# 19         entropy               6               None                      4
# 20         entropy               6               None                      4
# 21         entropy               6               None                      5
# 22         entropy               6               None                      5
# 23         entropy               6               None                      5
# 24         entropy               7               None                      2
# 25         entropy               7               None                      2
# 26         entropy               7               None                      2
# 27         entropy               7               None                      3
# 28         entropy               7               None                      3
# 29         entropy               7               None                      3
# 30         entropy               7               None                      4
# 31         entropy               7               None                      4
# 32         entropy               7               None                      4
# 33         entropy               7               None                      5
# 34         entropy               7               None                      5
# 35         entropy               7               None                      5
#
#    param_min_samples_split                                             params  \
# 0                       35  {u'max_features': None, u'min_samples_split': ...
# 1                       40  {u'max_features': None, u'min_samples_split': ...
# 2                       45  {u'max_features': None, u'min_samples_split': ...
# 3                       35  {u'max_features': None, u'min_samples_split': ...
# 4                       40  {u'max_features': None, u'min_samples_split': ...
# 5                       45  {u'max_features': None, u'min_samples_split': ...
# 6                       35  {u'max_features': None, u'min_samples_split': ...
# 7                       40  {u'max_features': None, u'min_samples_split': ...
# 8                       45  {u'max_features': None, u'min_samples_split': ...
# 9                       35  {u'max_features': None, u'min_samples_split': ...
# 10                      40  {u'max_features': None, u'min_samples_split': ...
# 11                      45  {u'max_features': None, u'min_samples_split': ...
# 12                      35  {u'max_features': None, u'min_samples_split': ...
# 13                      40  {u'max_features': None, u'min_samples_split': ...
# 14                      45  {u'max_features': None, u'min_samples_split': ...
# 15                      35  {u'max_features': None, u'min_samples_split': ...
# 16                      40  {u'max_features': None, u'min_samples_split': ...
# 17                      45  {u'max_features': None, u'min_samples_split': ...
# 18                      35  {u'max_features': None, u'min_samples_split': ...
# 19                      40  {u'max_features': None, u'min_samples_split': ...
# 20                      45  {u'max_features': None, u'min_samples_split': ...
# 21                      35  {u'max_features': None, u'min_samples_split': ...
# 22                      40  {u'max_features': None, u'min_samples_split': ...
# 23                      45  {u'max_features': None, u'min_samples_split': ...
# 24                      35  {u'max_features': None, u'min_samples_split': ...
# 25                      40  {u'max_features': None, u'min_samples_split': ...
# 26                      45  {u'max_features': None, u'min_samples_split': ...
# 27                      35  {u'max_features': None, u'min_samples_split': ...
# 28                      40  {u'max_features': None, u'min_samples_split': ...
# 29                      45  {u'max_features': None, u'min_samples_split': ...
# 30                      35  {u'max_features': None, u'min_samples_split': ...
# 31                      40  {u'max_features': None, u'min_samples_split': ...
# 32                      45  {u'max_features': None, u'min_samples_split': ...
# 33                      35  {u'max_features': None, u'min_samples_split': ...
# 34                      40  {u'max_features': None, u'min_samples_split': ...
# 35                      45  {u'max_features': None, u'min_samples_split': ...
#
#          ...         split5_test_score  split5_train_score  split6_test_score  \
# 0        ...                -14.160223          -13.137647         -14.459948
# 1        ...                -14.160223          -13.137647         -14.459948
# 2        ...                -14.135249          -13.151919         -14.459948
# 3        ...                -14.110275          -13.144783         -14.459948
# 4        ...                -14.110275          -13.144783         -14.459948
# 5        ...                -14.085301          -13.159055         -14.459948
# 6        ...                -14.110275          -13.144783         -14.459948
# 7        ...                -14.110275          -13.144783         -14.459948
# 8        ...                -14.085301          -13.159055         -14.459948
# 9        ...                -14.085301          -13.151919         -14.459948
# 10       ...                -14.085301          -13.151919         -14.459948
# 11       ...                -14.085301          -13.166191         -14.459948
# 12       ...                -14.135259          -12.809391         -14.385009
# 13       ...                -14.135259          -12.820095         -14.385009
# 14       ...                -14.110284          -12.834367         -14.434956
# 15       ...                -14.085311          -12.816527         -14.385009
# 16       ...                -14.085311          -12.827231         -14.385009
# 17       ...                -14.060337          -12.841503         -14.434956
# 18       ...                -14.035363          -12.820095         -14.385009
# 19       ...                -14.060337          -12.830799         -14.385009
# 20       ...                -14.035362          -12.845071         -14.434956
# 21       ...                -14.035362          -12.830799         -14.385009
# 22       ...                -14.035362          -12.837935         -14.385009
# 23       ...                -14.035362          -12.852207         -14.434956
# 24       ...                -14.310075          -12.502535         -14.210192
# 25       ...                -14.310075          -12.516807         -14.210192
# 26       ...                -14.285101          -12.531079         -14.260139
# 27       ...                -14.260128          -12.509671         -14.210192
# 28       ...                -14.260128          -12.523943         -14.210192
# 29       ...                -14.235153          -12.538215         -14.260139
# 30       ...                -14.210179          -12.516807         -14.210192
# 31       ...                -14.235153          -12.527511         -14.210192
# 32       ...                -14.210179          -12.541783         -14.260139
# 33       ...                -14.235153          -12.541783         -14.185218
# 34       ...                -14.235153          -12.548919         -14.185218
# 35       ...                -14.235153          -12.563191         -14.235165
#
#     split6_train_score  split7_test_score  split7_train_score  std_fit_time  \
# 0           -13.191194         -13.845614          -13.129186      0.040253
# 1           -13.191194         -13.845614          -13.129186      0.028892
# 2           -13.191194         -13.920589          -13.132753      0.120608
# 3           -13.191194         -13.845614          -13.129186      0.055934
# 4           -13.191194         -13.845614          -13.129186      0.051996
# 5           -13.191194         -13.920589          -13.132753      0.071295
# 6           -13.191194         -13.845614          -13.129186      0.207544
# 7           -13.191194         -13.845614          -13.129186      0.029075
# 8           -13.191194         -13.920589          -13.132753      0.093251
# 9           -13.191194         -13.845614          -13.132754      0.035795
# 10          -13.191194         -13.845614          -13.132754      0.053402
# 11          -13.191194         -13.920589          -13.136321      0.028575
# 12          -12.895027         -13.720627          -12.761687      0.029245
# 13          -12.895027         -13.720627          -12.761687      0.065578
# 14          -12.916435         -13.770610          -12.783092      0.029619
# 15          -12.895027         -13.720627          -12.761687      0.048777
# 16          -12.895027         -13.720627          -12.761687      0.098875
# 17          -12.916435         -13.770610          -12.783092      0.019855
# 18          -12.895027         -13.720627          -12.765254      0.055796
# 19          -12.895027         -13.720627          -12.765254      0.151893
# 20          -12.916435         -13.770610          -12.786660      0.243308
# 21          -12.909299         -13.695635          -12.768822      0.019527
# 22          -12.909299         -13.695635          -12.768822      0.060800
# 23          -12.930707         -13.745617          -12.790227      0.138438
# 24          -12.591741         -13.945579          -12.305041      0.026683
# 25          -12.591741         -13.945579          -12.305041      0.040620
# 26          -12.613149         -13.995561          -12.326446      0.037902
# 27          -12.591741         -13.945579          -12.305041      0.037654
# 28          -12.591741         -13.945579          -12.305041      0.013956
# 29          -12.613149         -13.995561          -12.326446      0.121428
# 30          -12.602445         -13.945579          -12.308609      0.032708
# 31          -12.602445         -13.945579          -12.308609      0.120674
# 32          -12.623853         -13.995561          -12.330014      0.045732
# 33          -12.630990         -13.920586          -12.312177      0.123983
# 34          -12.630990         -13.920586          -12.312177      0.120853
# 35          -12.652398         -13.970569          -12.333582      0.059848
#
#     std_score_time  std_test_score  std_train_score
# 0         0.009684        0.472814         0.111899
# 1         0.010363        0.472814         0.111899
# 2         0.003220        0.461693         0.110078
# 3         0.022511        0.478609         0.111112
# 4         0.005975        0.478609         0.111112
# 5         0.005525        0.468042         0.109361
# 6         0.010018        0.478609         0.111224
# 7         0.002284        0.478609         0.111224
# 8         0.005406        0.468042         0.109601
# 9         0.007817        0.481693         0.114634
# 10        0.007139        0.481693         0.114634
# 11        0.005367        0.468042         0.112769
# 12        0.012131        0.422878         0.135244
# 13        0.005356        0.422878         0.138962
# 14        0.005418        0.414869         0.142076
# 15        0.008109        0.426341         0.135286
# 16        0.004221        0.426341         0.139049
# 17        0.006906        0.419003         0.142153
# 18        0.008248        0.430047         0.135216
# 19        0.002720        0.427936         0.138901
# 20        0.004267        0.419376         0.140635
# 21        0.005822        0.434573         0.139168
# 22        0.003980        0.434573         0.143031
# 23        0.004252        0.423808         0.144971
# 24        0.003641        0.484567         0.175526
# 25        0.007556        0.487432         0.179966
# 26        0.004459        0.497746         0.184000
# 27        0.005251        0.485830         0.176148
# 28        0.003254        0.488126         0.180581
# 29        0.006970        0.498250         0.184610
# 30        0.003426        0.488607         0.175033
# 31        0.007655        0.489977         0.178419
# 32        0.009111        0.499577         0.183270
# 33        0.004435        0.523503         0.194767
# 34        0.004336        0.526283         0.198091
# 35        0.004334        0.534139         0.204531
#
# [36 rows x 31 columns]

# %% [markdown]
# ## Evaluating Model

# %%
# Train a new classifier using the best parameters found by the grid search
clf = DecisionTreeClassifier(random_state=0,
                             max_features=best_params['max_features'],
                             criterion=best_params['criterion'],
                             max_depth=best_params['max_depth'],
                             min_samples_split=best_params['min_samples_split'],
                             min_samples_leaf=best_params['min_samples_leaf']
                   )
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=6,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=35, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=0, splitter='best')

# %%
# Predict target values
y_pred = clf.predict(X_test)

# %%
# Predict probabilities
y_probs = clf.predict_proba(X_test)

# %%
# Compute cross-entropy score
from sklearn.metrics import log_loss
log_loss(y_test, y_pred)
# Out:
# 14.1520958110585

# %%
# Compute precision, recall, F-measure and support
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, y_pred, average='binary')
# Out:
# (0.5787234042553191, 0.31954887218045114, 0.41174689676052073, None)

# %%
# Compute the confusion Matrix
df_confusion = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
df_confusion
# Out:
# Predicted  False  True   All
# Actual
# False       2119   495  2614
# True        1448   680  2128
# All         3567  1175  4742

# %%
# Plot a ROC curve
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test.ravel(), y_probs[:, 1].ravel())
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('ROC')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# # ALL DATASET TEST

# %%
# Apply on all the dataset
X_pred = clf.predict(X)
df['pred'] = X_pred
df_bet_all_seasons = df.drop(df[df.pred == 0].index)

# %%
# How many bet I did
df_bet_all_seasons.shape
# Out:
# (3874, 192)

# %%
# What will be the real result of games I bet on
display(plt.show(), 100. * df_bet_all_seasons.INFO_FTR.value_counts() / len(df_bet_all_seasons.INFO_FTR))
# Out:
# None
# H    63.061435
# D    19.876097
# A    17.062468
# Name: INFO_FTR, dtype: float64

# %%
# Compute cross-entropy score
log_loss(y, X_pred)
# Out:
# 13.382892177561255

# %%
# Score for all dataset
precision_recall_fscore_support(y, X_pred, average='binary')
# Out:
# (0.63061435209086214, 0.34234865470852016, 0.44377838328792002, None)

# %%
# Making the confusion Matrix
df_confusion = pd.crosstab(y, X_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
df_confusion
# Out:
# Predicted  False  True    All
# Actual
# False       7238  1431   8669
# True        4693  2443   7136
# All        11931  3874  15805

# %%
df_bet_all_seasons.INFO_WIN.mean()
# Out:
# 0.09202891068662879

# %% [markdown]
# # SEASON 2016/2017 TEST

# %%
# Apply on current season that is not use for train and test set
X_pred_current_season = clf.predict(X_current_season)
X_prob_current_season = clf.predict_proba(X_current_season)
df_current_season['pred'] = X_pred_current_season
df_current_season['prob'] = X_prob_current_season[:,1:]
df_current_season['prob_less_bet'] = df_current_season['prob'] - df_current_season[odd].apply(lambda x: 1/x)

# %%
# Remove games I didn't bet on
df_bet_current_season = df_current_season.drop(df_current_season[df_current_season.pred == 0].index)
# df_bet_current_season = df_bet_current_season[df_bet_current_season.prob_less_bet > 0]
# df_bet_current_season = df_bet_current_season[df_bet_current_season[odd] > 2]
# df_bet_current_season = df_bet_current_season[df_bet_current_season[odd] < 4]

# %%
# How many bet I did
df_bet_current_season.shape
# Out:
# (557, 194)

# %%
# How many matches was play
X_pred_current_season.shape
# Out:
# (2222,)

# %%
# What will be the real result of games I bet on
display(plt.show(), 100. * df_bet_current_season.INFO_FTR.value_counts() / len(df_bet_current_season.INFO_FTR))
# Out:
# None
# H    62.118492
# D    20.287253
# A    17.594255
# Name: INFO_FTR, dtype: float64

# %%
# Compute cross-entropy score
log_loss(y_current_season, X_pred_current_season)
# Out:
# 14.518175458102768

# %%
# Score for this current season
precision_recall_fscore_support(y_current_season, X_pred_current_season, average='binary')
# Out:
# (0.62118491921005381, 0.32366697848456499, 0.42558425584255843, None)

# %%
# Making the confusion Matrix
df_confusion = pd.crosstab(y_current_season, X_pred_current_season, rownames=['Actual'], colnames=['Predicted'], margins=True)
df_confusion
# Out:
# Predicted  False  True   All
# Actual
# False        942   211  1153
# True         723   346  1069
# All         1665   557  2222

# %%
# What I win/lost on each match
df_bet_current_season.INFO_WIN.mean()
# Out:
# 0.03066427289048468

# %%
df_bet_current_season
# Out:
#        A_MEANS_FIVE_AC  A_MEANS_FIVE_AF  A_MEANS_FIVE_AR  A_MEANS_FIVE_AS  \
# 23053              4.0             12.0              0.0             10.0
# 23054              7.0              9.2              0.0             11.2
# 23061              3.4             11.4              0.0              9.2
# 23065              4.0             17.2              0.6              8.0
# 23066              3.6             12.8              0.2              7.8
# 23068              4.0             11.2              0.0             13.8
# 23069              3.2             13.0              0.0              8.4
# 23070              4.4             10.2              0.0             10.0
# 23075              6.4             11.4              0.0             13.8
# 23076              4.6             11.6              0.0             12.4
# 23079              4.2             13.8              0.0              8.8
# 23085              3.4             14.2              0.0              9.4
# 23088              5.2             13.8              0.0             14.2
# 23089              4.2              9.8              0.2              8.4
# 23094              4.8             13.4              0.0              9.6
# 23099              5.4             15.6              0.2              9.4
# 23107              3.8             11.0              0.0             12.4
# 23110              6.6             12.2              0.0             10.2
# 23111              4.2             15.8              0.2             10.2
# 23114              2.8             11.2              0.2              8.8
# 23118              4.4             16.4              0.2             11.0
# 23119              3.8             10.8              0.0             12.6
# 23120              3.0             17.0              0.0              8.6
# 23127              2.8              9.8              0.0              8.8
# 23135              4.8             12.6              0.0             11.8
# 23144              4.2             12.2              0.0              9.2
# 23159              4.2             12.4              0.0             11.4
# 23161              4.8             13.4              0.0             12.2
# 23163              6.4             10.8              0.2             14.4
# 23166              4.0             13.0              0.0             11.2
# ...                ...              ...              ...              ...
# 25196              4.0             13.6              0.0              9.8
# 25197              4.6             11.8              0.0             11.0
# 25198              6.0             11.2              0.0             11.6
# 25199              5.2             13.4              0.0              9.0
# 25203              4.2             12.8              0.4             10.4
# 25208              7.0             10.4              0.0             14.6
# 25211              2.2             15.8              0.0             10.6
# 25212              2.4             11.0              0.0             10.0
# 25217              2.4             12.4              0.0              8.2
# 25219              4.6             13.0              0.4              9.8
# 25221              2.4             12.0              0.2              8.8
# 25225              5.0             11.0              0.4              8.0
# 25227              2.4              9.8              0.2             11.2
# 25229              5.4             13.4              0.2             11.2
# 25239              3.8             14.0              0.2              8.0
# 25241              5.4             10.0              0.0             10.8
# 25243              2.6              9.2              0.2              8.4
# 25244              2.4             16.6              0.2              7.0
# 25245              5.0             11.0              0.0              9.4
# 25247              4.4             12.8              0.0              8.4
# 25251              6.0             13.0              0.0             11.4
# 25252              7.8             14.8              0.2             15.8
# 25253              3.4             15.0              0.2              8.0
# 25255              3.0              9.4              0.2             10.4
# 25256              6.8             11.2              0.0             14.2
# 25257              4.2             13.8              0.2              9.6
# 25265              2.8             14.8              0.2             10.4
# 25269              4.4             14.4              0.0             12.0
# 25270              5.0             12.2              0.0              8.8
# 25272              4.4             16.2              0.0             10.6
#
#        A_MEANS_FIVE_AST  A_MEANS_FIVE_AY  A_MEANS_FIVE_FTAG  \
# 23053               4.6              2.2                1.2
# 23054               2.8              1.4                0.4
# 23061               4.6              1.4                1.4
# 23065               2.2              2.0                0.6
# 23066               2.0              3.0                0.4
# 23068               5.6              1.8                1.4
# 23069               2.4              1.6                0.8
# 23070               3.6              2.0                1.0
# 23075               4.6              1.8                1.2
# 23076               3.4              2.2                0.8
# 23079               3.0              2.2                0.4
# 23085               3.6              3.4                0.8
# 23088               5.0              2.8                2.0
# 23089               3.8              3.4                1.0
# 23094               4.6              2.0                1.2
# 23099               3.6              2.0                0.8
# 23107               3.2              1.6                0.6
# 23110               3.4              2.6                1.0
# 23111               3.2              2.2                0.8
# 23114               3.2              2.8                1.0
# 23118               3.6              1.8                1.0
# 23119               5.8              2.6                3.4
# 23120               3.6              3.2                1.4
# 23127               2.4              1.4                1.0
# 23135               3.2              2.4                0.8
# 23144               3.8              2.0                1.0
# 23159               3.8              1.8                0.8
# 23161               4.0              3.2                1.0
# 23163               2.4              2.6                0.4
# 23166               4.8              3.6                1.8
# ...                 ...              ...                ...
# 25196               3.6              3.0                1.0
# 25197               3.0              1.4                0.0
# 25198               3.2              2.0                0.4
# 25199               2.2              2.8                0.8
# 25203               4.2              0.8                0.8
# 25208               5.2              2.0                1.2
# 25211               3.4              1.2                0.8
# 25212               4.6              1.8                3.0
# 25217               2.6              1.4                0.4
# 25219               2.8              1.6                0.8
# 25221               3.8              1.4                1.0
# 25225               1.8              1.6                0.4
# 25227               3.0              1.4                1.2
# 25229               5.0              2.0                0.8
# 25239               2.8              2.4                0.8
# 25241               3.4              2.0                0.4
# 25243               2.8              1.2                0.8
# 25244               2.0              2.0                0.4
# 25245               3.0              1.8                1.4
# 25247               2.0              2.8                0.6
# 25251               3.8              2.6                1.2
# 25252               5.6              1.0                2.4
# 25253               3.0              2.8                0.8
# 25255               4.2              1.8                1.6
# 25256               6.0              2.4                1.4
# 25257               4.0              3.0                1.0
# 25265               2.4              2.6                0.8
# 25269               4.2              2.6                0.6
# 25270               3.4              2.4                1.0
# 25272               2.8              1.6                0.4
#
#        A_MEANS_FIVE_FTHG  A_MEANS_FIVE_FTR_A  A_MEANS_FIVE_FTR_D  \
# 23053                1.2                 0.4                 0.0
# 23054                1.2                 0.0                 0.2
# 23061                1.2                 0.2                 0.6
# 23065                2.4                 0.2                 0.0
# 23066                1.4                 0.0                 0.2
# 23068                1.0                 0.4                 0.2
# 23069                1.0                 0.2                 0.6
# 23070                1.4                 0.2                 0.4
# 23075                2.0                 0.4                 0.0
# 23076                1.0                 0.4                 0.0
# 23079                1.2                 0.2                 0.2
# 23085                1.2                 0.2                 0.0
# 23088                1.6                 0.4                 0.4
# 23089                2.8                 0.2                 0.0
# 23094                1.8                 0.2                 0.4
# 23099                3.0                 0.0                 0.4
# 23107                1.8                 0.2                 0.2
# 23110                1.6                 0.4                 0.0
# 23111                2.2                 0.0                 0.2
# 23114                2.2                 0.0                 0.6
# 23118                1.4                 0.6                 0.0
# 23119                1.4                 0.8                 0.0
# 23120                2.2                 0.4                 0.0
# 23127                1.0                 0.2                 0.6
# 23135                1.0                 0.2                 0.6
# 23144                1.0                 0.2                 0.4
# 23159                1.0                 0.4                 0.2
# 23161                1.0                 0.2                 0.4
# 23163                1.6                 0.0                 0.4
# 23166                1.2                 0.4                 0.2
# ...                  ...                 ...                 ...
# 25196                2.0                 0.2                 0.2
# 25197                2.2                 0.0                 0.0
# 25198                1.2                 0.2                 0.0
# 25199                1.8                 0.0                 0.6
# 25203                1.2                 0.4                 0.2
# 25208                0.8                 0.6                 0.0
# 25211                1.8                 0.4                 0.2
# 25212                2.2                 0.4                 0.4
# 25217                3.0                 0.0                 0.2
# 25219                2.0                 0.2                 0.0
# 25221                3.0                 0.2                 0.2
# 25225                2.8                 0.2                 0.0
# 25227                1.0                 0.4                 0.4
# 25229                2.2                 0.0                 0.4
# 25239                1.6                 0.0                 0.4
# 25241                1.2                 0.2                 0.0
# 25243                1.4                 0.2                 0.6
# 25244                2.6                 0.0                 0.2
# 25245                2.0                 0.6                 0.0
# 25247                2.0                 0.0                 0.4
# 25251                1.2                 0.6                 0.2
# 25252                2.2                 0.2                 0.2
# 25253                1.4                 0.2                 0.2
# 25255                2.2                 0.4                 0.2
# 25256                1.0                 0.6                 0.0
# 25257                1.0                 0.4                 0.2
# 25265                2.4                 0.2                 0.2
# 25269                2.2                 0.0                 0.2
# 25270                2.2                 0.2                 0.2
# 25272                1.8                 0.2                 0.0
#
#            ...        INFO_FTR  INFO_HTR       INFO_HomeTeam  INFO_PSA  \
# 23053      ...               H         A         Bristol Rvs      4.13
# 23054      ...               H         D            Coventry      4.99
# 23061      ...               H         H       Ein Frankfurt      2.96
# 23065      ...               H         H          Leverkusen     12.44
# 23066      ...               A         D         Bournemouth      5.78
# 23068      ...               H         H             Chelsea      6.47
# 23069      ...               D         H            Man City     14.22
# 23070      ...               D         D            West Ham      4.13
# 23075      ...               H         H           Newcastle      8.10
# 23076      ...               A         H             Norwich      4.47
# 23079      ...               A         D      Sheffield Weds      5.99
# 23085      ...               H         H                Lyon      9.21
# 23088      ...               D         D              Napoli      5.50
# 23089      ...               H         H              Torino      6.29
# 23094      ...               H         D              Celtic     15.81
# 23099      ...               H         H          Schalke 04      5.88
# 23107      ...               H         H            Paris SG     16.00
# 23110      ...               D         D               Genoa      4.78
# 23111      ...               H         D               Inter     14.40
# 23114      ...               H         H                Roma     12.42
# 23118      ...               H         H         Real Madrid     22.50
# 23119      ...               A         D             Sevilla      1.69
# 23120      ...               H         H          Villarreal      7.36
# 23127      ...               D         A  Milton Keynes Dons      4.67
# 23135      ...               D         D            Brighton      4.78
# 23144      ...               A         H          M'gladbach      3.61
# 23159      ...               D         A              Fulham      3.35
# 23161      ...               D         D             Preston      3.14
# 23163      ...               H         H             Reading      3.96
# 23166      ...               D         D         Bristol Rvs      3.26
# ...        ...             ...       ...                 ...       ...
# 25196      ...               D         D          Villarreal      6.49
# 25197      ...               H         H             Chelsea     13.50
# 25198      ...               H         D             Arsenal     28.49
# 25199      ...               H         H            Man City     23.10
# 25203      ...               H         H              Monaco     13.50
# 25208      ...               A         A           Leicester      1.88
# 25211      ...               H         H       Bayern Munich     14.30
# 25212      ...               H         H            Dortmund     11.81
# 25217      ...               D         D          Hoffenheim      8.06
# 25219      ...               D         D          M'gladbach      9.02
# 25221      ...               H         H            Guingamp      5.35
# 25225      ...               H         D           Marseille     10.02
# 25227      ...               D         H            Paris SG     15.44
# 25229      ...               D         D            Toulouse      2.93
# 25239      ...               H         H             Arsenal      7.75
# 25241      ...               H         D             Chelsea     21.02
# 25243      ...               D         A           Leicester      4.35
# 25244      ...               H         H           Liverpool     27.82
# 25245      ...               H         H          Man United      3.14
# 25247      ...               H         A             Swansea      3.67
# 25251      ...               H         H            Juventus     22.02
# 25252      ...               A         A               Lazio      3.63
# 25253      ...               H         D               Milan      9.25
# 25255      ...               D         H             Udinese      3.81
# 25256      ...               H         H          Ath Madrid      3.99
# 25257      ...               H         A           Barcelona     40.35
# 25265      ...               H         D            Atalanta     10.75
# 25269      ...               D         A          Fiorentina       NaN
# 25270      ...               H         H               Inter      8.51
# 25272      ...               H         D                Roma       NaN
#
#        INFO_PSD  INFO_PSH  INFO_WIN  pred      prob  prob_less_bet
# 23053      3.74      1.94      0.92  True  0.590909       0.070076
# 23054      3.85      1.77      0.79  True  0.586517       0.027858
# 23061      3.20      2.70      1.61  True  0.606232       0.223091
# 23065      6.28      1.28      0.26  True  0.606232      -0.187418
# 23066      4.27      1.63     -1.00  True  0.606232      -0.011052
# 23068      4.37      1.57      0.56  True  0.538153      -0.102873
# 23069      7.16      1.23     -1.00  True  0.769663      -0.050009
# 23070      3.59      2.00     -1.00  True  0.586517       0.086517
# 23075      4.54      1.47      0.44  True  0.538153      -0.156292
# 23076      3.78      1.86     -1.00  True  0.538153      -0.011298
# 23079      3.52      1.74     -1.00  True  0.846154       0.264758
# 23085      4.49      1.44      0.42  True  0.769663       0.065438
# 23088      3.98      1.70     -1.00  True  0.689531       0.104735
# 23089      4.38      1.58      0.57  True  0.586517      -0.050426
# 23094      8.28      1.19      0.17  True  0.865169       0.010468
# 23099      4.41      1.61      0.59  True  0.586517      -0.042414
# 23107      6.80      1.23      0.23  True  0.769663      -0.043345
# 23110      3.45      1.92     -1.00  True  0.606232       0.071473
# 23111      6.46      1.26      0.25  True  0.586517      -0.213483
# 23114      6.41      1.28      0.26  True  0.689531      -0.104120
# 23118     15.00      1.10      0.08  True  0.769663      -0.156263
# 23119      4.51      4.84     -1.00  True  0.654545       0.450046
# 23120      4.31      1.53      0.52  True  0.606232      -0.051662
# 23127      3.80      1.82     -1.00  True  0.590909       0.035354
# 23135      3.32      1.96     -1.00  True  0.606232       0.082672
# 23144      3.38      2.23     -1.00  True  0.606232       0.151687
# 23159      3.32      2.35     -1.00  True  0.769663       0.338628
# 23161      3.38      2.43     -1.00  True  0.538153       0.119743
# 23163      3.51      2.05      1.01  True  0.606232       0.108720
# 23166      3.60      2.27     -1.00  True  0.590909       0.136364
# ...         ...       ...       ...   ...       ...            ...
# 25196      4.59      1.54     -1.00  True  0.606232      -0.043118
# 25197      6.85      1.25      0.24  True  0.840000       0.033548
# 25198     13.62      1.10      0.09  True  0.606232      -0.311199
# 25199     10.39      1.14      0.13  True  0.769663      -0.115293
# 25203      7.46      1.22      0.20  True  0.538153      -0.295181
# 25208      3.78      4.44     -1.00  True  0.865169       0.632068
# 25211      8.70      1.20      0.18  True  0.654545      -0.192912
# 25212      8.38      1.23      0.20  True  0.654545      -0.178788
# 25217      5.68      1.39     -1.00  True  0.606232      -0.134508
# 25219      5.86      1.35     -1.00  True  0.586517      -0.159752
# 25221      4.09      1.68      0.66  True  0.840000       0.237590
# 25225      5.89      1.32      0.31  True  0.606232      -0.157126
# 25227      8.01      1.20     -1.00  True  0.689531      -0.150805
# 25229      3.43      2.55     -1.00  True  0.606232       0.206232
# 25239      5.29      1.42      0.42  True  0.538153      -0.166073
# 25241      9.01      1.16      0.15  True  0.865169      -0.004397
# 25243      3.75      1.91     -1.00  True  0.654545       0.133712
# 25244      9.31      1.14      0.12  True  0.606232      -0.286625
# 25245      3.40      2.44      1.48  True  0.586517       0.183291
# 25247      3.68      2.10      1.06  True  0.606232       0.120795
# 25251      7.40      1.19      0.18  True  0.538153      -0.309305
# 25252      3.95      2.04     -1.00  True  0.620690       0.123177
# 25253      5.27      1.38      0.37  True  0.769663       0.039736
# 25255      3.52      2.11     -1.00  True  0.606232       0.125463
# 25256      3.66      2.00      1.00  True  0.689531       0.189531
# 25257     15.58      1.07      0.05  True  0.689531      -0.262850
# 25265      6.55      1.28      0.27  True  0.606232      -0.181169
# 25269       NaN       NaN     -1.00  True  0.865169      -0.004397
# 25270      5.60      1.37      0.36  True  0.769663       0.034369
# 25272       NaN       NaN      0.05  True  0.769663      -0.182718
#
# [557 rows x 194 columns]

# %% [markdown]
# # Learning Curve

# %%
# Plot a leqrning curve
from sklearn.datasets import load_digits
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit


def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring='f1')
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

plot_learning_curve(clf, 'Learning Curve', X, y, cv=4, n_jobs=-1).show()
plt.show()
