# %% [markdown]
# # Random Forest FTR HOME

# %%
# Importing the library
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O
import matplotlib.pyplot as plt # plotting library
import seaborn as sns # visualization library based on matplotlib
from IPython.display import display # Manage multiple output per cell
import datetime

# %%
all_features = ["A_MEANS_FIVE_AC","A_MEANS_FIVE_AF","A_MEANS_FIVE_AR","A_MEANS_FIVE_AS","A_MEANS_FIVE_AST","A_MEANS_FIVE_AY","A_MEANS_FIVE_FTAG","A_MEANS_FIVE_FTHG","A_MEANS_FIVE_FTR_A","A_MEANS_FIVE_FTR_D","A_MEANS_FIVE_FTR_H","A_MEANS_FIVE_HC","A_MEANS_FIVE_HF","A_MEANS_FIVE_HR","A_MEANS_FIVE_HS","A_MEANS_FIVE_HST","A_MEANS_FIVE_HTAG","A_MEANS_FIVE_HTHG","A_MEANS_FIVE_HTR_A","A_MEANS_FIVE_HTR_D","A_MEANS_FIVE_HTR_H","A_MEANS_FIVE_HY","H_MEANS_FIVE_AC","H_MEANS_FIVE_AF","H_MEANS_FIVE_AR","H_MEANS_FIVE_AS","H_MEANS_FIVE_AST","H_MEANS_FIVE_AY","H_MEANS_FIVE_FTAG","H_MEANS_FIVE_FTHG","H_MEANS_FIVE_FTR_A","H_MEANS_FIVE_FTR_D","H_MEANS_FIVE_FTR_H","H_MEANS_FIVE_HC","H_MEANS_FIVE_HF","H_MEANS_FIVE_HR","H_MEANS_FIVE_HS","H_MEANS_FIVE_HST","H_MEANS_FIVE_HTAG","H_MEANS_FIVE_HTHG","H_MEANS_FIVE_HTR_A","H_MEANS_FIVE_HTR_D","H_MEANS_FIVE_HTR_H","H_MEANS_FIVE_HY","A_MEANS_THREE_AC","A_MEANS_THREE_AF","A_MEANS_THREE_AR","A_MEANS_THREE_AS","A_MEANS_THREE_AST","A_MEANS_THREE_AY","A_MEANS_THREE_FTAG","A_MEANS_THREE_FTHG","A_MEANS_THREE_FTR_A","A_MEANS_THREE_FTR_D","A_MEANS_THREE_FTR_H","A_MEANS_THREE_HC","A_MEANS_THREE_HF","A_MEANS_THREE_HR","A_MEANS_THREE_HS","A_MEANS_THREE_HST","A_MEANS_THREE_HTAG","A_MEANS_THREE_HTHG","A_MEANS_THREE_HTR_A","A_MEANS_THREE_HTR_D","A_MEANS_THREE_HTR_H","A_MEANS_THREE_HY","H_MEANS_THREE_AC","H_MEANS_THREE_AF","H_MEANS_THREE_AR","H_MEANS_THREE_AS","H_MEANS_THREE_AST","H_MEANS_THREE_AY","H_MEANS_THREE_FTAG","H_MEANS_THREE_FTHG","H_MEANS_THREE_FTR_A","H_MEANS_THREE_FTR_D","H_MEANS_THREE_FTR_H","H_MEANS_THREE_HC","H_MEANS_THREE_HF","H_MEANS_THREE_HR","H_MEANS_THREE_HS","H_MEANS_THREE_HST","H_MEANS_THREE_HTAG","H_MEANS_THREE_HTHG","H_MEANS_THREE_HTR_A","H_MEANS_THREE_HTR_D","H_MEANS_THREE_HTR_H","H_MEANS_THREE_HY","A_STD_FIVE_AC","A_STD_FIVE_AF","A_STD_FIVE_AR","A_STD_FIVE_AS","A_STD_FIVE_AST","A_STD_FIVE_AY","A_STD_FIVE_FTAG","A_STD_FIVE_FTHG","A_STD_FIVE_FTR_A","A_STD_FIVE_FTR_D","A_STD_FIVE_FTR_H","A_STD_FIVE_HC","A_STD_FIVE_HF","A_STD_FIVE_HR","A_STD_FIVE_HS","A_STD_FIVE_HST","A_STD_FIVE_HTAG","A_STD_FIVE_HTHG","A_STD_FIVE_HTR_A","A_STD_FIVE_HTR_D","A_STD_FIVE_HTR_H","A_STD_FIVE_HY","H_STD_FIVE_AC","H_STD_FIVE_AF","H_STD_FIVE_AR","H_STD_FIVE_AS","H_STD_FIVE_AST","H_STD_FIVE_AY","H_STD_FIVE_FTAG","H_STD_FIVE_FTHG","H_STD_FIVE_FTR_A","H_STD_FIVE_FTR_D","H_STD_FIVE_FTR_H","H_STD_FIVE_HC","H_STD_FIVE_HF","H_STD_FIVE_HR","H_STD_FIVE_HS","H_STD_FIVE_HST","H_STD_FIVE_HTAG","H_STD_FIVE_HTHG","H_STD_FIVE_HTR_A","H_STD_FIVE_HTR_D","H_STD_FIVE_HTR_H","H_STD_FIVE_HY","A_STD_THREE_AC","A_STD_THREE_AF","A_STD_THREE_AR","A_STD_THREE_AS","A_STD_THREE_AST","A_STD_THREE_AY","A_STD_THREE_FTAG","A_STD_THREE_FTHG","A_STD_THREE_FTR_A","A_STD_THREE_FTR_D","A_STD_THREE_FTR_H","A_STD_THREE_HC","A_STD_THREE_HF","A_STD_THREE_HR","A_STD_THREE_HS","A_STD_THREE_HST","A_STD_THREE_HTAG","A_STD_THREE_HTHG","A_STD_THREE_HTR_A","A_STD_THREE_HTR_D","A_STD_THREE_HTR_H","A_STD_THREE_HY","H_STD_THREE_AC","H_STD_THREE_AF","H_STD_THREE_AR","H_STD_THREE_AS","H_STD_THREE_AST","H_STD_THREE_AY","H_STD_THREE_FTAG","H_STD_THREE_FTHG","H_STD_THREE_FTR_A","H_STD_THREE_FTR_D","H_STD_THREE_FTR_H","H_STD_THREE_HC","H_STD_THREE_HF","H_STD_THREE_HR","H_STD_THREE_HS","H_STD_THREE_HST","H_STD_THREE_HTAG","H_STD_THREE_HTHG","H_STD_THREE_HTR_A","H_STD_THREE_HTR_D","H_STD_THREE_HTR_H","H_STD_THREE_HY","INFO_Div"]
all_five_features = ["A_MEANS_FIVE_AC","A_MEANS_FIVE_AF","A_MEANS_FIVE_AR","A_MEANS_FIVE_AS","A_MEANS_FIVE_AST","A_MEANS_FIVE_AY","A_MEANS_FIVE_FTAG","A_MEANS_FIVE_FTHG","A_MEANS_FIVE_FTR_A","A_MEANS_FIVE_FTR_D","A_MEANS_FIVE_FTR_H","A_MEANS_FIVE_HC","A_MEANS_FIVE_HF","A_MEANS_FIVE_HR","A_MEANS_FIVE_HS","A_MEANS_FIVE_HST","A_MEANS_FIVE_HTAG","A_MEANS_FIVE_HTHG","A_MEANS_FIVE_HTR_A","A_MEANS_FIVE_HTR_D","A_MEANS_FIVE_HTR_H","A_MEANS_FIVE_HY","H_MEANS_FIVE_AC","H_MEANS_FIVE_AF","H_MEANS_FIVE_AR","H_MEANS_FIVE_AS","H_MEANS_FIVE_AST","H_MEANS_FIVE_AY","H_MEANS_FIVE_FTAG","H_MEANS_FIVE_FTHG","H_MEANS_FIVE_FTR_A","H_MEANS_FIVE_FTR_D","H_MEANS_FIVE_FTR_H","H_MEANS_FIVE_HC","H_MEANS_FIVE_HF","H_MEANS_FIVE_HR","H_MEANS_FIVE_HS","H_MEANS_FIVE_HST","H_MEANS_FIVE_HTAG","H_MEANS_FIVE_HTHG","H_MEANS_FIVE_HTR_A","H_MEANS_FIVE_HTR_D","H_MEANS_FIVE_HTR_H","H_MEANS_FIVE_HY","A_STD_FIVE_AC","A_STD_FIVE_AF","A_STD_FIVE_AR","A_STD_FIVE_AS","A_STD_FIVE_AST","A_STD_FIVE_AY","A_STD_FIVE_FTAG","A_STD_FIVE_FTHG","A_STD_FIVE_FTR_A","A_STD_FIVE_FTR_D","A_STD_FIVE_FTR_H","A_STD_FIVE_HC","A_STD_FIVE_HF","A_STD_FIVE_HR","A_STD_FIVE_HS","A_STD_FIVE_HST","A_STD_FIVE_HTAG","A_STD_FIVE_HTHG","A_STD_FIVE_HTR_A","A_STD_FIVE_HTR_D","A_STD_FIVE_HTR_H","A_STD_FIVE_HY","H_STD_FIVE_AC","H_STD_FIVE_AF","H_STD_FIVE_AR","H_STD_FIVE_AS","H_STD_FIVE_AST","H_STD_FIVE_AY","H_STD_FIVE_FTAG","H_STD_FIVE_FTHG","H_STD_FIVE_FTR_A","H_STD_FIVE_FTR_D","H_STD_FIVE_FTR_H","H_STD_FIVE_HC","H_STD_FIVE_HF","H_STD_FIVE_HR","H_STD_FIVE_HS","H_STD_FIVE_HST","H_STD_FIVE_HTAG","H_STD_FIVE_HTHG","H_STD_FIVE_HTR_A","H_STD_FIVE_HTR_D","H_STD_FIVE_HTR_H","H_STD_FIVE_HY","INFO_Div"]
all_three_features = ["A_MEANS_THREE_AC","A_MEANS_THREE_AF","A_MEANS_THREE_AR","A_MEANS_THREE_AS","A_MEANS_THREE_AST","A_MEANS_THREE_AY","A_MEANS_THREE_FTAG","A_MEANS_THREE_FTHG","A_MEANS_THREE_FTR_A","A_MEANS_THREE_FTR_D","A_MEANS_THREE_FTR_H","A_MEANS_THREE_HC","A_MEANS_THREE_HF","A_MEANS_THREE_HR","A_MEANS_THREE_HS","A_MEANS_THREE_HST","A_MEANS_THREE_HTAG","A_MEANS_THREE_HTHG","A_MEANS_THREE_HTR_A","A_MEANS_THREE_HTR_D","A_MEANS_THREE_HTR_H","A_MEANS_THREE_HY","H_MEANS_THREE_AC","H_MEANS_THREE_AF","H_MEANS_THREE_AR","H_MEANS_THREE_AS","H_MEANS_THREE_AST","H_MEANS_THREE_AY","H_MEANS_THREE_FTAG","H_MEANS_THREE_FTHG","H_MEANS_THREE_FTR_A","H_MEANS_THREE_FTR_D","H_MEANS_THREE_FTR_H","H_MEANS_THREE_HC","H_MEANS_THREE_HF","H_MEANS_THREE_HR","H_MEANS_THREE_HS","H_MEANS_THREE_HST","H_MEANS_THREE_HTAG","H_MEANS_THREE_HTHG","H_MEANS_THREE_HTR_A","H_MEANS_THREE_HTR_D","H_MEANS_THREE_HTR_H","H_MEANS_THREE_HY","A_STD_THREE_AC","A_STD_THREE_AF","A_STD_THREE_AR","A_STD_THREE_AS","A_STD_THREE_AST","A_STD_THREE_AY","A_STD_THREE_FTAG","A_STD_THREE_FTHG","A_STD_THREE_FTR_A","A_STD_THREE_FTR_D","A_STD_THREE_FTR_H","A_STD_THREE_HC","A_STD_THREE_HF","A_STD_THREE_HR","A_STD_THREE_HS","A_STD_THREE_HST","A_STD_THREE_HTAG","A_STD_THREE_HTHG","A_STD_THREE_HTR_A","A_STD_THREE_HTR_D","A_STD_THREE_HTR_H","A_STD_THREE_HY","H_STD_THREE_AC","H_STD_THREE_AF","H_STD_THREE_AR","H_STD_THREE_AS","H_STD_THREE_AST","H_STD_THREE_AY","H_STD_THREE_FTAG","H_STD_THREE_FTHG","H_STD_THREE_FTR_A","H_STD_THREE_FTR_D","H_STD_THREE_FTR_H","H_STD_THREE_HC","H_STD_THREE_HF","H_STD_THREE_HR","H_STD_THREE_HS","H_STD_THREE_HST","H_STD_THREE_HTAG","H_STD_THREE_HTHG","H_STD_THREE_HTR_A","H_STD_THREE_HTR_D","H_STD_THREE_HTR_H","H_STD_THREE_HY","INFO_Div"]
best_features_60 = ['A_MEANS_FIVE_AC', 'A_MEANS_FIVE_AS', 'A_MEANS_FIVE_AST',
       'A_MEANS_FIVE_AY', 'A_MEANS_FIVE_FTAG', 'A_MEANS_FIVE_FTHG',
       'A_MEANS_FIVE_FTR_A', 'A_MEANS_FIVE_FTR_H', 'A_MEANS_FIVE_HC',
       'A_MEANS_FIVE_HF', 'A_MEANS_FIVE_HS', 'A_MEANS_FIVE_HST',
       'A_MEANS_FIVE_HTHG', 'A_MEANS_FIVE_HTR_A', 'A_MEANS_FIVE_HY',
       'H_MEANS_FIVE_AC', 'H_MEANS_FIVE_AS', 'H_MEANS_FIVE_AST',
       'H_MEANS_FIVE_AY', 'H_MEANS_FIVE_FTAG', 'H_MEANS_FIVE_FTHG',
       'H_MEANS_FIVE_FTR_A', 'H_MEANS_FIVE_FTR_H', 'H_MEANS_FIVE_HC',
       'H_MEANS_FIVE_HF', 'H_MEANS_FIVE_HS', 'H_MEANS_FIVE_HST',
       'H_MEANS_FIVE_HTAG', 'H_MEANS_FIVE_HTR_A', 'H_MEANS_FIVE_HTR_H',
       'A_MEANS_THREE_AC', 'A_MEANS_THREE_AS', 'A_MEANS_THREE_FTHG',
       'A_MEANS_THREE_FTR_A', 'A_MEANS_THREE_HC', 'A_MEANS_THREE_HF',
       'A_MEANS_THREE_HS', 'A_MEANS_THREE_HST', 'H_MEANS_THREE_AC',
       'H_MEANS_THREE_AS', 'H_MEANS_THREE_AST', 'H_MEANS_THREE_FTHG',
       'H_MEANS_THREE_HC', 'H_MEANS_THREE_HST', 'H_MEANS_THREE_HTR_H',
       'A_STD_FIVE_AF', 'A_STD_FIVE_AS', 'A_STD_FIVE_AST', 'A_STD_FIVE_HC',
       'A_STD_FIVE_HF', 'A_STD_FIVE_HS', 'H_STD_FIVE_AF', 'H_STD_FIVE_AS',
       'H_STD_FIVE_AST', 'H_STD_FIVE_HC', 'H_STD_FIVE_HF',
       'H_STD_FIVE_HST', 'H_STD_FIVE_HTHG', 'H_STD_THREE_AS',
       'H_STD_THREE_HST']
features_list = all_features

# %%
model_name = 'XGBOOST_FTR_GT2_LT4_LOG_LOSS'
odd_H = 'INFO_BbAvH'
odd_A = 'INFO_BbAvA'
odd_D = 'INFO_BbAvD'
target = 'INFO_FTR'
start_date = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M")
min_odd = 2
max_odd = 4

# %% [markdown]
# ## Importing Data

# %%
# DB Sqlite connection
import sqlite3
db = "/Users/thibaultclement/Project/ligue1-predict/src/notebook/data/db/soccer_predict.sqlite"
conn = sqlite3.connect(db)
cur = conn.cursor()

# %%
# Get all prematch data
df = pd.read_sql_query("SELECT * FROM pre_matchs ORDER BY INFO_Date ASC;", conn)
df = (df[df.columns.drop(['index'])])
df.shape
# Out:
# (37907, 190)

# %%
# Remove all game between June (include) and October (include)
df['INFO_Date'] = pd.to_datetime(df['INFO_Date'])
df['INFO_Date'].dt.month
df = df[(df['INFO_Date'].dt.month < 6) | (df['INFO_Date'].dt.month > 10)]
df.shape
# Out:
# (26988, 190)

# %%
# Remove too small odd
#df = df[(df[odd_H] > min_odd) & (df[odd_A] > min_odd)]
#df = df[(df[odd_H] < max_odd) & (df[odd_A] < max_odd)]
df.shape
# Out:
# (26988, 190)

# %%
# Select a particular league
df = df[(df['INFO_Div'] == 'F1')]
#df = df[(df['INFO_Div'] == 'E0')]
df.shape
# Out:
# (3214, 190)

# %%
# Removing column where odd is too high or too low
# df = df.drop(df[df['INFO_BbAvH'] < 2].index)
# df = df.drop(df[df['INFO_BbAvA'] < 2].index)
# df = df.drop(df[df['INFO_BbAvH'] > 10].index)
# df = df.drop(df[df['INFO_BbAvA'] > 10].index)
df.shape
# Out:
# (3214, 190)

# %%
# Create a INFO_WIN column containing the gain if you bet the good result
df['INFO_WIN'] = 0
df.loc[df.INFO_FTR == 'H', 'INFO_WIN'] = df[odd_H]
df.loc[df.INFO_FTR == 'A', 'INFO_WIN'] = df[odd_A]
df.loc[df.INFO_FTR == 'D', 'INFO_WIN'] = df[odd_D]
df['INFO_WIN_P'] = 0
df.loc[df.INFO_FTR == 'H', 'INFO_WIN_P'] = df['INFO_PSH']
df.loc[df.INFO_FTR == 'A', 'INFO_WIN_P'] = df['INFO_PSA']
df.loc[df.INFO_FTR == 'D', 'INFO_WIN_P'] = df['INFO_PSD']
df[[odd_H, odd_D, odd_A, 'INFO_FTR', 'INFO_WIN']].head(10)
# Out:
#       INFO_BbAvH  INFO_BbAvD  INFO_BbAvA INFO_FTR  INFO_WIN
# 1040        2.43        2.88        2.83        H      2.43
# 1041        2.32        2.86        3.02        H      2.32
# 1042        2.01        2.91        3.73        H      2.01
# 1043        2.48        2.79        2.86        A      2.86
# 1044        2.02        2.93        3.62        D      2.93
# 1045        4.25        3.08        1.82        A      1.82
# 1061        1.59        3.33        5.59        H      1.59
# 1062        1.96        2.98        3.78        D      2.98
# 1063        2.42        2.82        2.93        D      2.82
# 1064        2.46        2.84        2.85        H      2.46

# %%
# Statistic about winners
display(plt.show(), 100. * df.INFO_FTR.value_counts() / len(df.INFO_FTR))
# Out:
# None
# H    45.177349
# D    28.718108
# A    26.104543
# Name: INFO_FTR, dtype: float64

# %%
# How much did you win/lost per match if bet on all
df.INFO_WIN.mean()
# Out:
# 2.735668948350967

# %%
# Keep season 2016/2017 for further test and don't use it for traning
import datetime
date_start_learn = datetime.date(2007, 8, 1)
date_end_learn = datetime.date(2016, 8, 1)
date_start_current_season = datetime.date(2016, 8, 1)
date_end_current_season = datetime.date(2017, 8, 1)
df_current_season = df[(df['INFO_Date'] > date_start_current_season)]
df_current_season = df_current_season[(df_current_season['INFO_Date'] < date_end_current_season)]
df = df[(df['INFO_Date'] > date_start_learn)]
df = df[(df['INFO_Date'] < date_end_learn)]

# %%
# Remove too small odd
#df = df[(df[odd_H] > min_odd) & (df[odd_A] > min_odd)]
#df = df[(df[odd_H] < max_odd) & (df[odd_A] < max_odd)]
display(plt.show(), 100. * df.INFO_FTR.value_counts() / len(df.INFO_FTR))
# Out:
# None
# H    44.985555
# D    28.270739
# A    26.743706
# Name: INFO_FTR, dtype: float64

# %%
df.shape
# Out:
# (2423, 192)

# %%
# Number of matches in current season
df_current_season.shape
# Out:
# (270, 192)

# %%
# Encode string label
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df[target])
# Prepare the dataset
X = pd.get_dummies(df[features_list])
y = le.transform(df[target]) 
X_current_season = pd.get_dummies(df_current_season[features_list])
y_current_season = le.transform(df_current_season[target])

# %% [markdown]
# ## Preprocessing Data

# %%
# Standardize features
#from sklearn.preprocessing import StandardScaler
#sc_X = StandardScaler().fit(X)
#X = sc_X.transform(X)
#X_current_season = sc_X.transform(X_current_season)

# %%
# Impute of missing values (NaN) with the mean
from sklearn.preprocessing import Imputer
#imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
#imp = imp.fit(X)
#X = imp.transform(X)
#X_current_season = imp.transform(X_current_season)

# %%
# Split the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 0)

# %% [markdown]
# ## Tuning Hyper-parameters

# %%
# Import model
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
classifier = XGBClassifier(nthread=4, seed=15)
# Out:
# /anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# # Plot a learning curve
# from sklearn.datasets import load_digits
# from sklearn.model_selection import learning_curve
# from sklearn.model_selection import ShuffleSplit
# 
# 
# def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
#                         n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5)):
#     plt.figure()
#     plt.title(title)
#     if ylim is not None:
#         plt.ylim(*ylim)
#     plt.xlabel("Training examples")
#     plt.ylabel("Score")
#     train_sizes, train_scores, test_scores = learning_curve(
#         estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
#     train_scores_mean = np.mean(train_scores, axis=1)
#     train_scores_std = np.std(train_scores, axis=1)
#     test_scores_mean = np.mean(test_scores, axis=1)
#     test_scores_std = np.std(test_scores, axis=1)
#     plt.grid()
# 
#     plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
#                      train_scores_mean + train_scores_std, alpha=0.1,
#                      color="r")
#     plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
#                      test_scores_mean + test_scores_std, alpha=0.1, color="g")
#     plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
#              label="Training score")
#     plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
#              label="Cross-validation score")
# 
#     plt.legend(loc="best")
#     return plt
# 
# clf = XGBClassifier(learning_rate =0.01,n_estimators=207,max_depth=3,min_child_weight=3,gamma=0.4,subsample=0.65,colsample_bytree=0.85,objective= 'multi:softprob',nthread=4,scale_pos_weight=1,seed=15)
# plot_learning_curve(clf, 'Learning Curve', X, y, cv=8, n_jobs=-1).show()
# plt.show()

# %%
# Applying Grid Search to find the best hyper-parameters for our Model
from sklearn.model_selection import GridSearchCV
from sklearn.metrics.classification import log_loss
from sklearn.metrics import make_scorer
import time

start = time.time()

parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [163],
    'max_depth': [5],
    'min_child_weight': [1],
    'gamma': [0],
    'subsample': [0.8],
    'colsample_bytree': [0.8],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1],
    'reg_alpha':[0]
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [163],
    'max_depth': [3, 5, 7], # 3
    'min_child_weight': [1, 3, 5], # 3
    'gamma': [0],
    'subsample': [0.8],
    'colsample_bytree': [0.8],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1]
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [163],
    'max_depth': [3],
    'min_child_weight': [3],
    'gamma': [0.03, 0.0, 0.3], # 0.3
    'subsample': [0.8],
    'colsample_bytree': [0.8],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1]
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [163],
    'max_depth': [3],
    'min_child_weight': [3],
    'gamma': [0.1, 0.3, 0.5, 1], # 0.3
    'subsample': [0.8],
    'colsample_bytree': [0.8],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1]
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [163],
    'max_depth': [3],
    'min_child_weight': [3],
    'gamma': [0.2, 0.3, 0.4], # 0.4
    'subsample': [0.8],
    'colsample_bytree': [0.8],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1]
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [209],
    'max_depth': [3],
    'min_child_weight': [3],
    'gamma': [0.4],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1],
    'subsample': [0.7, 0.8, 0.9], # 0.7
    'colsample_bytree': [0.7, 0.8, 0.9], # 0.8
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [209],
    'max_depth': [3],
    'min_child_weight': [3],
    'gamma': [0.4],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1],
    'subsample': [0.65, 0.7, 0.75], # 0.65
    'colsample_bytree': [0.75, 0.8, 0.85], # 0.85
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [209],
    'max_depth': [3],
    'min_child_weight': [3],
    'gamma': [0.4],
    'subsample': [0.8],
    'colsample_bytree': [0.8],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1],
    'subsample': [0.5, 0.55, 0.6, 0.65], # 0.65
    'colsample_bytree': [0.85], # 0.85
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [205],
    'max_depth': [3],
    'min_child_weight': [3],
    'gamma': [0.4],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1],
    'subsample': [0.65],
    'colsample_bytree': [0.85],
    'reg_alpha':[0, 1e-5, 1e-2, 0.1, 1, 10] # 0.1
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [205],
    'max_depth': [3],
    'min_child_weight': [3],
    'gamma': [0.4],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1],
    'subsample': [0.65],
    'colsample_bytree': [0.85],
    'reg_alpha':[0.05, 0.08, 0.1, 0.3, 0.5] # 0.05
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [205],
    'max_depth': [3],
    'min_child_weight': [3],
    'gamma': [0.4],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1],
    'subsample': [0.65],
    'colsample_bytree': [0.85],
    'reg_alpha':[0.03, 0.04, 0.05, 0.06] # 0.06
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [205],
    'max_depth': [3],
    'min_child_weight': [3],
    'gamma': [0.4],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1],
    'subsample': [0.65],
    'colsample_bytree': [0.85],
    'reg_alpha':[0.05, 0.06, 0.07, 0.08] # 0.06
}]
parameters = [{
    'learning_rate': [0.01],
    'n_estimators': [207],
    'max_depth': [3],
    'min_child_weight': [3],
    'gamma': [0.4],
    'objective': ['multi:softprob'],
    'scale_pos_weight': [1],
    'subsample': [0.65],
    'colsample_bytree': [0.85],
    'reg_alpha':[0.6]
}]
grid_search = GridSearchCV(estimator=classifier,
                           param_grid=parameters,
                           scoring=make_scorer(log_loss, greater_is_better=False, needs_proba=True),
                           cv=8,
                           n_jobs=-1,
                           verbose=1)
grid_search.fit(X_train, y_train)

time.time() - start
# Out:
# Fitting 8 folds for each of 1 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:   12.5s finished
# 15.632974863052368

# %%
# Extract best score calculated with the GridSearchCV
best_score = grid_search.best_score_
display(best_score)
# Out:
# -1.0520157766581144

# %%
# Extract best hyper-parameter calculated with the GridSearchCV
best_params = grid_search.best_params_
best_params
# Out:
# {'colsample_bytree': 0.85,
#  'gamma': 0.4,
#  'learning_rate': 0.01,
#  'max_depth': 3,
#  'min_child_weight': 3,
#  'n_estimators': 207,
#  'objective': 'multi:softprob',
#  'reg_alpha': 0.6,
#  'scale_pos_weight': 1,
#  'subsample': 0.65}

# %%
# Get all results of Grid Search
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results.to_csv('./tuning/'+model_name+'-'+target+'_'+start_date+'.csv')
cv_results
# Out:
#    mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0       6.120322         0.016387        -1.052016         -0.940823
#
#   param_colsample_bytree param_gamma param_learning_rate param_max_depth  \
# 0                   0.85         0.4                0.01               3
#
#   param_min_child_weight param_n_estimators       ...         \
# 0                      3                207       ...
#
#   split5_test_score split5_train_score split6_test_score split6_train_score  \
# 0         -1.032331          -0.945306         -1.055706          -0.940763
#
#   split7_test_score  split7_train_score  std_fit_time  std_score_time  \
# 0         -1.060229            -0.93864      0.595106        0.006325
#
#    std_test_score  std_train_score
# 0        0.009775         0.002556
#
# [1 rows x 36 columns]

# %% [markdown]
# ## Evaluating Model

# %%
# Train a new classifier using the best parameters found by the grid search
clf = XGBClassifier(
    nthread=4, 
    seed=15,
    learning_rate=best_params['learning_rate'],
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_child_weight=best_params['min_child_weight'],
    gamma=best_params['gamma'],
    subsample=best_params['subsample'],
    colsample_bytree=best_params['colsample_bytree'],
    objective=best_params['objective'],
    scale_pos_weight=best_params['scale_pos_weight'],
    reg_alpha=best_params['reg_alpha']
)
clf.fit(X_train, y_train, eval_metric='logloss')
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.85,
#        gamma=0.4, learning_rate=0.01, max_delta_step=0, max_depth=3,
#        min_child_weight=3, missing=None, n_estimators=207, nthread=4,
#        objective='multi:softprob', reg_alpha=0.6, reg_lambda=1,
#        scale_pos_weight=1, seed=15, silent=True, subsample=0.65)

# %%
# Predict target values
y_pred = clf.predict(X_test)

# %%
# Predict probabilities
y_probs = clf.predict_proba(X_test)

# %%
# Compute cross-entropy score
from sklearn.metrics import log_loss
log_loss(y_test, y_probs)
# Out:
# 1.030322597148166

# %%
# Compute precision, recall, F-measure and support
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=['A', 'D', 'H']))
# Out:
#              precision    recall  f1-score   support
#
#           A       0.42      0.24      0.30       191
#           D       0.39      0.04      0.07       185
#           H       0.52      0.89      0.66       351
#
# avg / total       0.46      0.50      0.41       727

# %%
# Plot a ROC curve
from sklearn.metrics import roc_auc_score
#roc_auc_score(y_test, y_pred)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.50068775790921594

# %% [markdown]
# # ALL DATASET TEST

# %%
# Apply on all the dataset
X_pred = clf.predict(X)
X_probs = clf.predict_proba(X)

df['pred'] = le.inverse_transform(X_pred)

df['probs_A'] = X_probs[:,0]
df['probs_D'] = X_probs[:,1]
df['probs_H'] = X_probs[:,2]
#df['probs_A'] = X_probs[:,0]
#df['probs_D'] = X_probs[:,1]
#df['probs_H'] = X_probs[:,2]
df['probs'] = df[['probs_A','probs_D','probs_H']].max(axis=1)

df['WIN'] = -1
df.loc[df.INFO_FTR == df.pred, 'WIN'] = df['INFO_WIN']

df_bet_all_seasons = df.drop(df[df.pred == 'X'].index)

# %%
#df[['probs_A','probs_D','probs_H','pred', 'INFO_FTR', 'WIN']]

# %%
# Compute cross-entropy score
log_loss(y, X_probs)
# Out:
# 0.97613838297790401

# %%
# Compute precision, recall, F-measure and support
from sklearn.metrics import classification_report
print(classification_report(y, X_pred, target_names=['A', 'D', 'H']))
# Out:
#              precision    recall  f1-score   support
#
#           A       0.62      0.37      0.47       648
#           D       0.84      0.14      0.24       685
#           H       0.53      0.93      0.67      1090
#
# avg / total       0.64      0.56      0.49      2423

# %%
df_bet_all_seasons.shape
# Out:
# (2423, 198)

# %%
# What will be the real result of games I bet on
display(plt.show(), 100. * df_bet_all_seasons.INFO_FTR.value_counts() / len(df_bet_all_seasons.INFO_FTR))
# Out:
# None
# H    44.985555
# D    28.270739
# A    26.743706
# Name: INFO_FTR, dtype: float64

# %%
df_bet_all_seasons.WIN.mean()
# Out:
# 0.7669005365249696

# %% [markdown]
# # SEASON 2016/2017 TEST

# %%
# Apply on current season that is not use for train and test set
X_pred_current_season = clf.predict(X_current_season)
X_prob_current_season = clf.predict_proba(X_current_season)

df_current_season['probs_A'] = X_prob_current_season[:,0]
df_current_season['probs_D'] = X_prob_current_season[:,1]
df_current_season['probs_H'] = X_prob_current_season[:,2]
df_current_season['probs'] = df_current_season[['probs_A','probs_D','probs_H']].max(axis=1)

df_current_season['pred'] = le.inverse_transform(X_pred_current_season)

df_current_season['GOOD'] = False
df_current_season.loc[df_current_season.INFO_FTR == df_current_season.pred, 'GOOD'] = True

df_current_season['WIN'] = -1
df_current_season.loc[df_current_season.INFO_FTR == df_current_season.pred, 'WIN'] = df_current_season['INFO_WIN']-1

df_current_season['WIN_P'] = -1
df_current_season.loc[df_current_season.INFO_FTR == df_current_season.pred, 'WIN_P'] = df_current_season['INFO_WIN_P']-1

df_current_season['INFO_ODD'] = 0
df_current_season.loc[df_current_season.pred == 'A', 'INFO_ODD_BET'] = df_current_season[odd_A]
df_current_season.loc[df_current_season.pred == 'D', 'INFO_ODD_BET'] = df_current_season[odd_D]
df_current_season.loc[df_current_season.pred == 'H', 'INFO_ODD_BET'] = df_current_season[odd_H]

#TODO
# test prob_less_bet <= 0.2 et si ceux que je predisais H je les mettais A en fait !

df_current_season['prob_less_bet'] = 0
df_current_season.loc[df_current_season.pred == 'A', 'prob_less_bet'] = df_current_season['probs'] - df_current_season[odd_A].apply(lambda x: 1/x)
df_current_season.loc[df_current_season.pred == 'D', 'prob_less_bet'] = df_current_season['probs'] - df_current_season[odd_D].apply(lambda x: 1/x)
df_current_season.loc[df_current_season.pred == 'H', 'prob_less_bet'] = df_current_season['probs'] - df_current_season[odd_H].apply(lambda x: 1/x)

# %%
# How many matches was play
X_pred_current_season.shape
# Out:
# (270,)

# %%
# Score for this current season
from sklearn.metrics import classification_report
print(classification_report(y_current_season, X_pred_current_season, target_names=['A', 'D', 'H']))
# Out:
#              precision    recall  f1-score   support
#
#           A       0.42      0.37      0.39        73
#           D       0.00      0.00      0.00        69
#           H       0.51      0.82      0.63       128
#
# avg / total       0.36      0.49      0.41       270

# %%
# Remove games I didn't bet on
df_bet_current_season = df_current_season
#df_bet_current_season = df_bet_current_season.drop(df_bet_current_season[df_bet_current_season.probs <= 0.6].index)
#df_bet_current_season = df_bet_current_season.drop(df_bet_current_season[df_bet_current_season.pred != 'A'].index)
#df_bet_current_season = df_bet_current_season.drop(df_bet_current_season[df_bet_current_season.pred == 'D'].index)
#df_bet_current_season = df_bet_current_season.drop(df_bet_current_season[df_bet_current_season.prob_less_bet <= 0].index)
#df_bet_current_season = df_bet_current_season[df_bet_current_season.prob_less_bet > 0]
#df_bet_current_season = df_bet_current_season[df_bet_current_season['INFO_ODD_BET'] > 1.9]
#df_bet_current_season = df_bet_current_season[df_bet_current_season['INFO_ODD_BET'] < 1.9]
#df_bet_current_season = df_bet_current_season[df_bet_current_season['INFO_Div'] == 'SC0']

# %%
# How many bet I did
df_bet_current_season.shape
# Out:
# (270, 203)

# %%
# What will be the real result of games I bet on
display(plt.show(), 100. * df_bet_current_season.INFO_FTR.value_counts() / len(df_bet_current_season.INFO_FTR))
# Out:
# None
# H    47.407407
# A    27.037037
# D    25.555556
# Name: INFO_FTR, dtype: float64

# %%
# What will I bet on
display(plt.show(), 100. * df_bet_current_season.pred.value_counts() / len(df_bet_current_season.pred))
# Out:
# None
# H    75.555556
# A    23.703704
# D     0.740741
# Name: pred, dtype: float64

# %%
# How good I will be
display(plt.show(), 100. * df_bet_current_season.GOOD.value_counts() / len(df_bet_current_season.GOOD))
# Out:
# None
# False    51.111111
# True     48.888889
# Name: GOOD, dtype: float64

# %%
# Compute cross-entropy score
log_loss(y_current_season, X_prob_current_season)
# Out:
# 1.027647872986617

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_current_season, X_pred_current_season)
# Out:
# 0.48888888888888887

# %%
df_bet_current_season.probs.mean()
# Out:
# 0.4253702461719513

# %%
df_bet_current_season[df_bet_current_season['GOOD'] == 1].INFO_WIN.mean()
# Out:
# 1.922424242424242

# %%
df_bet_current_season[df_bet_current_season['GOOD'] == 1].INFO_WIN_P.mean()
# Out:
# 1.9549242424242426

# %%
# What I win/lost on each match
df_bet_current_season.WIN.mean()
# Out:
# -0.06014814814814816

# %%
df_bet_current_season.WIN_P.mean()
# Out:
# -0.044259259259259255

# %%
df_bet_current_season[['INFO_Date', 'probs_A','probs_D','probs_H', 'probs', 'prob_less_bet', 'pred', 'INFO_FTR', 'WIN']]
#df_bet_current_season[['INFO_Div', 'INFO_Date', 'probs_A','probs_D','probs_H', 'probs', 'prob_less_bet', 'pred', 'INFO_FTR', 'GOOD', 'INFO_ODD_BET', 'WIN', 'WIN_P']].to_csv('./report/TEST-I1.csv')
# Out:
#        INFO_Date   probs_A   probs_D   probs_H     probs  prob_less_bet pred  \
# 35689 2016-11-04  0.259015  0.308182  0.432803  0.432803       0.054015    H
# 35714 2016-11-05  0.305900  0.284797  0.409303  0.409303      -0.007364    H
# 35715 2016-11-05  0.334636  0.328791  0.336573  0.336573      -0.218982    H
# 35716 2016-11-05  0.367248  0.271216  0.361536  0.367248       0.035022    A
# 35717 2016-11-05  0.204683  0.300926  0.494392  0.494392      -0.209834    H
# 35718 2016-11-05  0.272054  0.270786  0.457160  0.457160      -0.213981    H
# 35719 2016-11-05  0.314642  0.263010  0.422348  0.422348      -0.012434    H
# 35737 2016-11-06  0.354120  0.296571  0.349309  0.354120      -0.067821    A
# 35738 2016-11-06  0.437882  0.288608  0.273510  0.437882      -0.045210    A
# 35739 2016-11-06  0.193534  0.275468  0.530998  0.530998      -0.282010    H
# 35768 2016-11-18  0.413535  0.293168  0.293297  0.413535       0.007031    A
# 35769 2016-11-18  0.344227  0.326954  0.328818  0.344227      -0.202221    A
# 35808 2016-11-19  0.237170  0.334351  0.428479  0.428479       0.064843    H
# 35809 2016-11-19  0.267425  0.345384  0.387191  0.387191      -0.086743    H
# 35810 2016-11-19  0.220827  0.269830  0.509343  0.509343      -0.317103    H
# 35811 2016-11-19  0.266611  0.302051  0.431338  0.431338      -0.007259    H
# 35812 2016-11-19  0.252207  0.246230  0.501563  0.501563      -0.165103    H
# 35828 2016-11-20  0.269820  0.342165  0.388015  0.388015      -0.018489    H
# 35829 2016-11-20  0.284959  0.294052  0.420988  0.420988      -0.153724    H
# 35830 2016-11-20  0.316671  0.311751  0.371578  0.371578      -0.097906    H
# 35859 2016-11-25  0.336456  0.242178  0.421366  0.421366       0.013202    H
# 35894 2016-11-26  0.262785  0.323448  0.413767  0.413767      -0.167628    H
# 35895 2016-11-26  0.287302  0.303608  0.409090  0.409090      -0.014639    H
# 35896 2016-11-26  0.390037  0.310597  0.299366  0.390037       0.025073    A
# 35897 2016-11-26  0.193149  0.286006  0.520846  0.520846      -0.085215    H
# 35898 2016-11-26  0.266641  0.288288  0.445070  0.445070      -0.065134    H
# 35899 2016-11-26  0.299575  0.329285  0.371140  0.371140      -0.065541    H
# 35916 2016-11-27  0.327637  0.274472  0.397891  0.397891      -0.002109    H
# 35917 2016-11-27  0.335392  0.267905  0.396702  0.396702       0.112612    H
# 35918 2016-11-27  0.240327  0.293599  0.466074  0.466074      -0.139986    H
# ...          ...       ...       ...       ...       ...            ...  ...
# 37722 2017-05-06  0.239557  0.309093  0.451350  0.451350      -0.020348    H
# 37723 2017-05-06  0.256314  0.302531  0.441155  0.441155      -0.161254    H
# 37724 2017-05-06  0.390596  0.302783  0.306621  0.390596       0.089391    A
# 37725 2017-05-06  0.425421  0.292202  0.282377  0.425421      -0.254851    A
# 37726 2017-05-06  0.217665  0.298982  0.483352  0.483352      -0.417549    H
# 37727 2017-05-06  0.324929  0.288736  0.386335  0.386335      -0.072380    H
# 37754 2017-05-07  0.234380  0.271457  0.494163  0.494163      -0.094072    H
# 37755 2017-05-07  0.364536  0.275238  0.360226  0.364536       0.104119    A
# 37756 2017-05-07  0.378954  0.288911  0.332135  0.378954       0.065474    A
# 37803 2017-05-14  0.314255  0.281379  0.404366  0.404366       0.076497    H
# 37804 2017-05-14  0.297840  0.289406  0.412753  0.412753       0.001231    H
# 37805 2017-05-14  0.408121  0.286252  0.305627  0.408121       0.183402    A
# 37806 2017-05-14  0.233422  0.331083  0.435495  0.435495      -0.062018    H
# 37807 2017-05-14  0.265235  0.314707  0.420058  0.420058       0.024801    H
# 37808 2017-05-14  0.218286  0.213413  0.568301  0.568301      -0.286400    H
# 37809 2017-05-14  0.322791  0.271911  0.405299  0.405299       0.078501    H
# 37810 2017-05-14  0.215033  0.303452  0.481516  0.481516      -0.008680    H
# 37811 2017-05-14  0.424387  0.259960  0.315654  0.424387       0.216918    A
# 37812 2017-05-14  0.474509  0.254011  0.271480  0.474509      -0.266232    A
# 37835 2017-05-17  0.253923  0.258969  0.487108  0.487108      -0.346225    H
# 37852 2017-05-20  0.230724  0.289086  0.480191  0.480191       0.006257    H
# 37853 2017-05-20  0.206960  0.297722  0.495318  0.495318      -0.107092    H
# 37854 2017-05-20  0.272940  0.341432  0.385628  0.385628      -0.029310    H
# 37855 2017-05-20  0.318345  0.288367  0.393288  0.393288      -0.013216    H
# 37856 2017-05-20  0.334009  0.288195  0.377796  0.377796      -0.247204    H
# 37857 2017-05-20  0.231793  0.277604  0.490603  0.490603      -0.272756    H
# 37858 2017-05-20  0.294713  0.343710  0.361578  0.361578      -0.110120    H
# 37859 2017-05-20  0.258678  0.271542  0.469779  0.469779      -0.370557    H
# 37860 2017-05-20  0.523180  0.248656  0.228164  0.523180       0.037743    A
# 37861 2017-05-20  0.268719  0.362574  0.368706  0.368706      -0.031294    H
#
#       INFO_FTR   WIN
# 35689        H  1.64
# 35714        H  1.40
# 35715        H  0.80
# 35716        D -1.00
# 35717        H  0.42
# 35718        H  0.49
# 35719        D -1.00
# 35737        H -1.00
# 35738        D -1.00
# 35739        H  0.23
# 35768        A  1.46
# 35769        A  0.83
# 35808        D -1.00
# 35809        H  1.11
# 35810        H  0.21
# 35811        D -1.00
# 35812        A -1.00
# 35828        D -1.00
# 35829        H  0.74
# 35830        A -1.00
# 35859        H  1.45
# 35894        H  0.72
# 35895        D -1.00
# 35896        D -1.00
# 35897        H  0.65
# 35898        D -1.00
# 35899        D -1.00
# 35916        A -1.00
# 35917        A -1.00
# 35918        D -1.00
# ...        ...   ...
# 37722        H  1.12
# 37723        A -1.00
# 37724        D -1.00
# 37725        A  0.47
# 37726        H  0.11
# 37727        A -1.00
# 37754        H  0.70
# 37755        H -1.00
# 37756        H -1.00
# 37803        H  2.05
# 37804        D -1.00
# 37805        A  3.45
# 37806        H  1.01
# 37807        D -1.00
# 37808        H  0.17
# 37809        A -1.00
# 37810        H  1.04
# 37811        A  3.82
# 37812        A  0.35
# 37835        H  0.20
# 37852        H  1.11
# 37853        H  0.66
# 37854        H  1.41
# 37855        D -1.00
# 37856        D -1.00
# 37857        H  0.31
# 37858        H  1.12
# 37859        D -1.00
# 37860        A  1.06
# 37861        D -1.00
#
# [270 rows x 9 columns]

# %% [markdown]
# # Learning Curve

# %%
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot
# fit model no training data
model = XGBClassifier(
    learning_rate=0.01,
    n_estimators=207,
    max_depth=3,
    min_child_weight=3,
    gamma=0.4,
    subsample=0.65,
    colsample_bytree=0.85,
    objective= 'multi:softprob',
    nthread=4,
    scale_pos_weight=1,
    seed=15)
model.fit(X, y, eval_metric='logloss')
# plot feature importance
fig, ax = plt.subplots(figsize=(30,30))
plot_importance(model, ax=ax)
pyplot.show()

# %%
df_bet_current_season
# Out:
#        A_MEANS_FIVE_AC  A_MEANS_FIVE_AF  A_MEANS_FIVE_AR  A_MEANS_FIVE_AS  \
# 35689              4.0            15.20              0.2             7.80
# 35714              3.6            13.60              0.2            11.00
# 35715              4.6            12.40              0.2            12.60
# 35716              2.4            14.00              0.6             6.80
# 35717              3.4            14.20              0.0             9.40
# 35718              4.2            15.00              0.0             7.00
# 35719              2.4            17.40              0.0             7.80
# 35737              2.6             9.80              0.0            12.60
# 35738              4.2            15.00              0.2             9.80
# 35739              3.8            11.00              0.0            12.40
# 35768              5.0            13.40              0.4            13.60
# 35769              4.2            14.60              0.2            11.40
# 35808              3.0            12.00              0.2             9.00
# 35809              3.8            12.80              0.4             8.20
# 35810              4.0            15.80              0.0            12.80
# 35811              6.0            12.00              0.0            12.20
# 35812              4.2            16.80              0.2             8.00
# 35828              3.0             7.80              0.0             9.60
# 35829              4.4            10.00              0.0            10.60
# 35830              3.0            11.40              0.0            11.40
# 35859              2.0            15.80              0.0             6.80
# 35894              4.4            14.20              0.4             9.20
# 35895              2.4            15.40              0.6             6.80
# 35896              5.6            12.60              0.2            12.80
# 35897              3.8            14.00              0.2             8.20
# 35898              4.0            17.00              0.0             7.00
# 35899              3.2            14.20              0.2             9.60
# 35916              3.2            14.00              0.4             8.60
# 35917              4.4            11.60              0.2            12.60
# 35918              3.0            14.80              0.4             8.20
# ...                ...              ...              ...              ...
# 37722              2.8            13.80              0.2             8.80
# 37723              2.6            12.40              0.2             8.40
# 37724              3.6            11.00              0.2            12.80
# 37725              6.2            13.00              0.0            14.20
# 37726              5.6            11.60              0.6             9.20
# 37727              2.4            10.60              0.2            11.20
# 37754              4.6            12.60              0.0            12.60
# 37755              3.4            11.60              0.2             9.40
# 37756              4.8             9.80              0.2            12.80
# 37803              4.8            10.60              0.0             8.40
# 37804              6.4            10.60              0.0            13.60
# 37805              5.6            16.00              0.0            12.40
# 37806              4.2            14.60              0.4             7.20
# 37807              4.2            15.00              0.0             9.00
# 37808              4.0            14.60              0.0            13.20
# 37809              8.0            12.75              0.0            14.25
# 37810              5.6            11.00              0.2            10.40
# 37811              4.4             9.80              0.2            11.80
# 37812              6.6            10.20              0.4            14.60
# 37835              4.2            12.80              0.4            10.40
# 37852              5.6             9.00              0.2            12.00
# 37853              2.4            12.00              0.2             8.80
# 37854              4.2            14.80              0.0            11.00
# 37855              5.2            12.40              0.2            12.60
# 37856              4.2            10.20              0.0            11.80
# 37857              5.0            11.00              0.4             8.00
# 37858              4.0            12.00              0.2            10.00
# 37859              2.4             9.80              0.2            11.20
# 37860              5.6            12.40              0.0            14.60
# 37861              5.4            13.40              0.2            11.20
#
#        A_MEANS_FIVE_AST  A_MEANS_FIVE_AY  A_MEANS_FIVE_FTAG  \
# 35689              2.80              1.4                1.2
# 35714              2.60              1.4                0.8
# 35715              3.80              2.0                0.6
# 35716              3.60              1.8                1.2
# 35717              3.60              3.4                0.8
# 35718              2.40              2.6                0.6
# 35719              2.00              4.0                0.6
# 35737              5.40              1.0                2.0
# 35738              3.20              1.6                1.0
# 35739              3.20              1.6                0.6
# 35768              4.80              2.0                0.8
# 35769              5.80              1.6                2.6
# 35808              3.40              1.0                1.8
# 35809              2.60              1.6                0.4
# 35810              4.40              2.2                1.0
# 35811              4.40              2.0                0.8
# 35812              2.60              3.0                0.8
# 35828              3.40              1.0                1.4
# 35829              3.80              1.4                0.6
# 35830              5.00              1.4                1.4
# 35859              2.40              4.2                0.8
# 35894              3.20              1.8                0.4
# 35895              3.60              1.8                1.4
# 35896              3.60              2.0                0.4
# 35897              2.60              1.4                1.2
# 35898              2.40              2.4                0.6
# 35899              2.00              1.0                0.4
# 35916              2.60              1.2                0.6
# 35917              4.40              1.2                2.0
# 35918              3.00              3.0                0.4
# ...                 ...              ...                ...
# 37722              4.60              2.8                1.2
# 37723              3.40              2.0                0.6
# 37724              4.80              1.4                1.6
# 37725              5.60              0.8                1.8
# 37726              2.40              1.2                0.4
# 37727              3.20              1.0                1.0
# 37754              4.80              1.8                1.6
# 37755              4.20              2.0                1.2
# 37756              4.00              1.0                1.4
# 37803              3.20              2.0                1.4
# 37804              5.00              2.6                1.8
# 37805              4.40              2.0                0.4
# 37806              2.60              2.4                0.4
# 37807              3.40              2.6                0.6
# 37808              4.80              1.8                1.4
# 37809              4.25              1.5                2.0
# 37810              3.80              1.4                0.2
# 37811              4.60              1.0                1.4
# 37812              6.00              1.4                2.6
# 37835              4.20              0.8                0.8
# 37852              3.20              1.0                0.8
# 37853              3.80              1.4                1.0
# 37854              4.60              1.8                1.6
# 37855              3.40              2.0                1.0
# 37856              4.40              1.8                1.2
# 37857              1.80              1.6                0.4
# 37858              4.00              1.0                0.6
# 37859              3.00              1.4                1.2
# 37860              6.40              1.0                2.2
# 37861              5.00              2.0                0.8
#
#        A_MEANS_FIVE_FTHG  A_MEANS_FIVE_FTR_A  A_MEANS_FIVE_FTR_D  \
# 35689                1.8                 0.0                 0.4
# 35714                1.8                 0.0                 0.2
# 35715                1.8                 0.0                 0.0
# 35716                1.0                 0.4                 0.0
# 35717                1.2                 0.2                 0.0
# 35718                0.8                 0.2                 0.4
# 35719                0.8                 0.2                 0.4
# 35737                1.0                 0.8                 0.2
# 35738                1.2                 0.2                 0.4
# 35739                1.8                 0.2                 0.2
# 35768                1.6                 0.2                 0.2
# 35769                1.8                 0.4                 0.2
# 35808                3.4                 0.0                 0.6
# 35809                1.6                 0.0                 0.4
# 35810                1.8                 0.2                 0.2
# 35811                1.2                 0.4                 0.0
# 35812                0.4                 0.4                 0.2
# 35828                0.8                 0.4                 0.4
# 35829                1.8                 0.0                 0.2
# 35830                0.8                 0.6                 0.2
# 35859                1.0                 0.2                 0.4
# 35894                1.6                 0.0                 0.4
# 35895                1.6                 0.2                 0.2
# 35896                1.6                 0.0                 0.0
# 35897                2.0                 0.0                 0.4
# 35898                1.6                 0.2                 0.4
# 35899                1.4                 0.0                 0.2
# 35916                0.6                 0.2                 0.6
# 35917                1.2                 0.6                 0.0
# 35918                1.6                 0.0                 0.0
# ...                  ...                 ...                 ...
# 37722                2.2                 0.0                 0.4
# 37723                4.0                 0.0                 0.2
# 37724                2.2                 0.4                 0.0
# 37725                0.6                 0.8                 0.2
# 37726                2.4                 0.2                 0.0
# 37727                1.4                 0.2                 0.4
# 37754                1.8                 0.4                 0.4
# 37755                0.6                 0.6                 0.4
# 37756                1.8                 0.4                 0.0
# 37803                1.4                 0.4                 0.0
# 37804                0.4                 0.4                 0.6
# 37805                1.2                 0.0                 0.6
# 37806                1.6                 0.0                 0.0
# 37807                1.8                 0.2                 0.2
# 37808                0.8                 0.6                 0.2
# 37809                0.8                 0.6                 0.2
# 37810                2.8                 0.0                 0.2
# 37811                2.2                 0.2                 0.2
# 37812                1.4                 0.8                 0.0
# 37835                1.2                 0.4                 0.2
# 37852                2.0                 0.2                 0.0
# 37853                3.0                 0.2                 0.2
# 37854                2.0                 0.4                 0.2
# 37855                1.2                 0.2                 0.4
# 37856                1.0                 0.4                 0.4
# 37857                2.8                 0.2                 0.0
# 37858                1.2                 0.4                 0.2
# 37859                1.0                 0.4                 0.4
# 37860                0.4                 1.0                 0.0
# 37861                2.2                 0.0                 0.4
#
#            ...         probs_D   probs_H     probs  pred   GOOD   WIN  WIN_P  \
# 35689      ...        0.308182  0.432803  0.432803     H   True  1.64   1.75
# 35714      ...        0.284797  0.409303  0.409303     H   True  1.40   1.42
# 35715      ...        0.328791  0.336573  0.336573     H   True  0.80   0.81
# 35716      ...        0.271216  0.361536  0.367248     A  False -1.00  -1.00
# 35717      ...        0.300926  0.494392  0.494392     H   True  0.42   0.44
# 35718      ...        0.270786  0.457160  0.457160     H   True  0.49   0.50
# 35719      ...        0.263010  0.422348  0.422348     H  False -1.00  -1.00
# 35737      ...        0.296571  0.349309  0.354120     A  False -1.00  -1.00
# 35738      ...        0.288608  0.273510  0.437882     A  False -1.00  -1.00
# 35739      ...        0.275468  0.530998  0.530998     H   True  0.23   0.23
# 35768      ...        0.293168  0.293297  0.413535     A   True  1.46   1.53
# 35769      ...        0.326954  0.328818  0.344227     A   True  0.83   0.85
# 35808      ...        0.334351  0.428479  0.428479     H  False -1.00  -1.00
# 35809      ...        0.345384  0.387191  0.387191     H   True  1.11   1.14
# 35810      ...        0.269830  0.509343  0.509343     H   True  0.21   0.22
# 35811      ...        0.302051  0.431338  0.431338     H  False -1.00  -1.00
# 35812      ...        0.246230  0.501563  0.501563     H  False -1.00  -1.00
# 35828      ...        0.342165  0.388015  0.388015     H  False -1.00  -1.00
# 35829      ...        0.294052  0.420988  0.420988     H   True  0.74   0.78
# 35830      ...        0.311751  0.371578  0.371578     H  False -1.00  -1.00
# 35859      ...        0.242178  0.421366  0.421366     H   True  1.45   1.48
# 35894      ...        0.323448  0.413767  0.413767     H   True  0.72   0.74
# 35895      ...        0.303608  0.409090  0.409090     H  False -1.00  -1.00
# 35896      ...        0.310597  0.299366  0.390037     A  False -1.00  -1.00
# 35897      ...        0.286006  0.520846  0.520846     H   True  0.65   0.66
# 35898      ...        0.288288  0.445070  0.445070     H  False -1.00  -1.00
# 35899      ...        0.329285  0.371140  0.371140     H  False -1.00  -1.00
# 35916      ...        0.274472  0.397891  0.397891     H  False -1.00  -1.00
# 35917      ...        0.267905  0.396702  0.396702     H  False -1.00  -1.00
# 35918      ...        0.293599  0.466074  0.466074     H  False -1.00  -1.00
# ...        ...             ...       ...       ...   ...    ...   ...    ...
# 37722      ...        0.309093  0.451350  0.451350     H   True  1.12   1.14
# 37723      ...        0.302531  0.441155  0.441155     H  False -1.00  -1.00
# 37724      ...        0.302783  0.306621  0.390596     A  False -1.00  -1.00
# 37725      ...        0.292202  0.282377  0.425421     A   True  0.47   0.49
# 37726      ...        0.298982  0.483352  0.483352     H   True  0.11   0.12
# 37727      ...        0.288736  0.386335  0.386335     H  False -1.00  -1.00
# 37754      ...        0.271457  0.494163  0.494163     H   True  0.70   0.70
# 37755      ...        0.275238  0.360226  0.364536     A  False -1.00  -1.00
# 37756      ...        0.288911  0.332135  0.378954     A  False -1.00  -1.00
# 37803      ...        0.281379  0.404366  0.404366     H   True  2.05   2.15
# 37804      ...        0.289406  0.412753  0.412753     H  False -1.00  -1.00
# 37805      ...        0.286252  0.305627  0.408121     A   True  3.45   3.74
# 37806      ...        0.331083  0.435495  0.435495     H   True  1.01   1.01
# 37807      ...        0.314707  0.420058  0.420058     H  False -1.00  -1.00
# 37808      ...        0.213413  0.568301  0.568301     H   True  0.17   0.19
# 37809      ...        0.271911  0.405299  0.405299     H  False -1.00  -1.00
# 37810      ...        0.303452  0.481516  0.481516     H   True  1.04   1.05
# 37811      ...        0.259960  0.315654  0.424387     A   True  3.82   3.94
# 37812      ...        0.254011  0.271480  0.474509     A   True  0.35   0.38
# 37835      ...        0.258969  0.487108  0.487108     H   True  0.20   0.22
# 37852      ...        0.289086  0.480191  0.480191     H   True  1.11   1.11
# 37853      ...        0.297722  0.495318  0.495318     H   True  0.66   0.68
# 37854      ...        0.341432  0.385628  0.385628     H   True  1.41   1.45
# 37855      ...        0.288367  0.393288  0.393288     H  False -1.00  -1.00
# 37856      ...        0.288195  0.377796  0.377796     H  False -1.00  -1.00
# 37857      ...        0.277604  0.490603  0.490603     H   True  0.31   0.32
# 37858      ...        0.343710  0.361578  0.361578     H   True  1.12   1.11
# 37859      ...        0.271542  0.469779  0.469779     H  False -1.00  -1.00
# 37860      ...        0.248656  0.228164  0.523180     A   True  1.06   1.09
# 37861      ...        0.362574  0.368706  0.368706     H  False -1.00  -1.00
#
#        INFO_ODD  INFO_ODD_BET  prob_less_bet
# 35689         0          2.64       0.054015
# 35714         0          2.40      -0.007364
# 35715         0          1.80      -0.218982
# 35716         0          3.01       0.035022
# 35717         0          1.42      -0.209834
# 35718         0          1.49      -0.213981
# 35719         0          2.30      -0.012434
# 35737         0          2.37      -0.067821
# 35738         0          2.07      -0.045210
# 35739         0          1.23      -0.282010
# 35768         0          2.46       0.007031
# 35769         0          1.83      -0.202221
# 35808         0          2.75       0.064843
# 35809         0          2.11      -0.086743
# 35810         0          1.21      -0.317103
# 35811         0          2.28      -0.007259
# 35812         0          1.50      -0.165103
# 35828         0          2.46      -0.018489
# 35829         0          1.74      -0.153724
# 35830         0          2.13      -0.097906
# 35859         0          2.45       0.013202
# 35894         0          1.72      -0.167628
# 35895         0          2.36      -0.014639
# 35896         0          2.74       0.025073
# 35897         0          1.65      -0.085215
# 35898         0          1.96      -0.065134
# 35899         0          2.29      -0.065541
# 35916         0          2.50      -0.002109
# 35917         0          3.52       0.112612
# 35918         0          1.65      -0.139986
# ...         ...           ...            ...
# 37722         0          2.12      -0.020348
# 37723         0          1.66      -0.161254
# 37724         0          3.32       0.089391
# 37725         0          1.47      -0.254851
# 37726         0          1.11      -0.417549
# 37727         0          2.18      -0.072380
# 37754         0          1.70      -0.094072
# 37755         0          3.84       0.104119
# 37756         0          3.19       0.065474
# 37803         0          3.05       0.076497
# 37804         0          2.43       0.001231
# 37805         0          4.45       0.183402
# 37806         0          2.01      -0.062018
# 37807         0          2.53       0.024801
# 37808         0          1.17      -0.286400
# 37809         0          3.06       0.078501
# 37810         0          2.04      -0.008680
# 37811         0          4.82       0.216918
# 37812         0          1.35      -0.266232
# 37835         0          1.20      -0.346225
# 37852         0          2.11       0.006257
# 37853         0          1.66      -0.107092
# 37854         0          2.41      -0.029310
# 37855         0          2.46      -0.013216
# 37856         0          1.60      -0.247204
# 37857         0          1.31      -0.272756
# 37858         0          2.12      -0.110120
# 37859         0          1.19      -0.370557
# 37860         0          2.06       0.037743
# 37861         0          2.50      -0.031294
#
# [270 rows x 203 columns]
